# %% [markdown]
# # Import Library

# %%
import tensorflow as tf
import time
import tensorflow_datasets as tfds
import tensorflow_hub as hub

# %%
import os
import json
import zipfile
import random
import numpy as np
import seaborn as sns
import tifffile as tiff
import cv2
from pycocotools.coco import COCO
from functools import partial
import matplotlib.pyplot as plt
import albumentations as A
import rasterio
from rasterio.transform import from_origin
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models, Input, optimizers, losses, metrics
from tensorflow.keras.layers import Input, Dropout, Attention, Lambda, SpatialDropout2D
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Reshape, Multiply
from tensorflow.keras.layers import Conv2D, GlobalMaxPooling2D, Add, Activation, Concatenate, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from collections import defaultdict
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Add
# Out:
# /home/ailaboratory/.pyenv/versions/3.10.12/lib/python3.10/site-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.7'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [markdown]
# # Import Data

# %% [markdown]
# # Load Data

# %%
# LOAD COCO

def load_coco_annotations(annotation_file):
    coco = COCO(annotation_file)
    used_category_ids = set()
    for img_id in coco.getImgIds():
        ann_ids = coco.getAnnIds(imgIds=img_id)
        anns = coco.loadAnns(ann_ids)
        used_category_ids.update(ann['category_id'] for ann in anns)
    valid_category_ids = sorted(list(used_category_ids))
    category_dict_coco_original_name_to_new_dense_idx = {
        coco.loadCats(cat_id)[0]['name']: idx for idx, cat_id in enumerate(valid_category_ids)
    }
    return coco, category_dict_coco_original_name_to_new_dense_idx

# %% [markdown]
# # Preprocess

# %%
def coco_to_multiclass_mask(coco, image_id, image_size, selected_classes_list, coco_name_to_original_dense_idx_map):
    height, width = image_size
    final_mask = np.zeros((height, width), dtype=np.uint8)

    ann_ids = coco.getAnnIds(imgIds=[image_id])
    anns = coco.loadAnns(ann_ids)

    for ann in anns:
        category_id_coco = ann["category_id"]
        category_name_coco = coco.loadCats([category_id_coco])[0]["name"]
        if category_name_coco in selected_classes_list:
            target_class_id = selected_classes_list.index(category_name_coco) + 1
            
            segmentation = coco.annToMask(ann)
            if segmentation.shape[0] != height or segmentation.shape[1] != width:
                segmentation = cv2.resize(segmentation, (width, height), interpolation=cv2.INTER_NEAREST)
            
            final_mask[segmentation == 1] = target_class_id
            
    return final_mask

# %%
def save_singlelayer_tiff(array, filename):
    if array.ndim != 2: 
        raise ValueError("Input array must be 2D with shape (H, W)")

    height, width = array.shape
    transform = from_origin(0, 0, 1, 1)
    metadata = {
        "driver": "GTiff",
        "height": height,
        "width": width,
        "count": 1, 
        "dtype": array.dtype,
        "crs": None,
        "transform": transform
    }
    with rasterio.open(filename, "w", **metadata) as dst:
        dst.write(array, 1)

# %%
def process_dataset_to_multiclass_tiff(annotation_file, output_folder, selected_classes_list_for_masking):
    os.makedirs(output_folder, exist_ok=True)
    coco, _ = load_coco_annotations(annotation_file)

    print(f"Target classes for mask generation: {selected_classes_list_for_masking}")
    for img_info in coco.dataset["images"]:
        image_id = img_info["id"]
        file_name = img_info["file_name"]
        image_size = (img_info["height"], img_info["width"])

        mask_hw = coco_to_multiclass_mask(coco, image_id, image_size, selected_classes_list_for_masking, _) 
        
        output_path = os.path.join(output_folder, file_name.replace(".jpg", ".tiff").replace(".png", ".tiff").replace(".jpeg", ".tiff"))
        save_singlelayer_tiff(mask_hw, output_path)
    print("Finished processing dataset to Multi-Class TIFFs.")

# %%
# scan-gizi-makan-coba-3-classes
coco, dictclass = load_coco_annotations("./datasetmakanan/train/_annotations.coco.json")
print(dictclass)
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# {'ayam_goreng': 0, 'nasi': 1, 'rendang': 2, 'sayur_kangkung': 3, 'sayursop': 4, 'tahu_goreng': 5, 'telur_dadar': 6, 'tempe_goreng': 7}

# %% [markdown]
# # SET APA GITU

# %%
ANNOTATION_FILE_TRAIN = "./datasetmakanan/train/_annotations.coco.json"
IMAGE_FOLDER_TRAIN = "./datasetmakanan/train/"
MASK_OUTPUT_FOLDER_TRAIN = "./datasetmakanan/mask_multiclass_tf"

# %%
SELECTED_CLASSES = ['nasi', 'ayam_goreng', 'rendang', 'sayur_kangkung', 'sayursop', 'telur_dadar']
NUM_MODEL_CLASSES = len(SELECTED_CLASSES) + 1
TARGET_SIZE = (320, 320)
BATCH_SIZE = 8
GROUPS_FOR_GN = 16

# %% [markdown]
# # Data Splitting

# %%
print(f"Generating Multi-Class masks for {len(SELECTED_CLASSES)} foreground classes...")
process_dataset_to_multiclass_tiff(ANNOTATION_FILE_TRAIN, MASK_OUTPUT_FOLDER_TRAIN, SELECTED_CLASSES)
# Out:
# Generating Multi-Class masks for 6 foreground classes...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Target classes for mask generation: ['nasi', 'ayam_goreng', 'rendang', 'sayur_kangkung', 'sayursop', 'telur_dadar']
# /home/ailaboratory/.pyenv/versions/3.10.12/lib/python3.10/site-packages/rasterio/__init__.py:366: NotGeoreferencedWarning: The given matrix is equal to Affine.identity or its flipped counterpart. GDAL may ignore this matrix and save no geotransform without raising an error. This behavior is somewhat driver-specific.
#   dataset = writer(
# Finished processing dataset to Multi-Class TIFFs.

# %%
image_files = sorted([f for f in os.listdir(IMAGE_FOLDER_TRAIN) if f.endswith(('.png', '.jpg', '.jpeg'))])
mask_files_mc = sorted([f for f in os.listdir(MASK_OUTPUT_FOLDER_TRAIN) if f.endswith('.tiff')])

# %%
image_mask_pairs_mc = []
for img_name in image_files:
    mask_name = img_name.rsplit('.', 1)[0] + ".tiff"
    if mask_name in mask_files_mc: # Gunakan mask_files_mc
        mask_path = os.path.join(MASK_OUTPUT_FOLDER_TRAIN, mask_name)
        try:
            mask_content_hw = tiff.imread(mask_path) 
            
            if np.any(mask_content_hw > 0): 
                image_mask_pairs_mc.append((os.path.join(IMAGE_FOLDER_TRAIN, img_name), mask_path))
            else:
                print(f"Mask {mask_name} only contains background. Skipping.")
        except Exception as e:
            print(f"Error reading or processing mask {mask_path} for emptiness check: {e}")

print(f"Found {len(image_mask_pairs_mc)} valid image-mask pairs (with foreground objects).")
# Out:
# Mask FG_tempegorengv2_100_jpg.rf.740e593769ab171b4ba2b8bf6da1350a.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_101_jpg.rf.3c82ed60b121bb5bf7a7c05e57cea4ae.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_102_jpg.rf.c99168096da9dce291d1ae254dc149d5.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_103_jpg.rf.9db54443e62de6d6ca20be3b57dfe13a.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_104_jpg.rf.04c78819f5f110bccb6b1bccd0929380.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_105_jpg.rf.25ec8b91e5c936721f73e8acac9c9f82.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_106_jpg.rf.cff235f6040d6b1298777b9f8c255448.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_107_jpg.rf.4d94af69e513a28d56574680f6d74c48.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_108_jpg.rf.d52a928acca2105bd594e607a1d33761.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_109_jpg.rf.312f4380c5ca4aa2d837bcfbd5734f52.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_110_jpg.rf.ac9bb0ad37ac92103e4323fd83c72ad9.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_111_jpg.rf.0d0d2ef76489355f403a88d8951a09b5.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_112_jpg.rf.1c9fd765ba99f56c1a7794d6372dd72b.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_113_jpg.rf.504c46fda74ba0f5ab643aedc0a5006f.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_114_jpg.rf.7eed81d3f0f8895656ac03c80c8a3302.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_115_jpg.rf.c6158f294e8c85ed3054a8352993ed96.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_116_jpg.rf.0677346ac2eb6920ad8be177cb42e7bf.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_117_jpg.rf.f5f872f8bba0459ba7a9c663d5455fa7.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_118_jpg.rf.64256248a1c7937515f74d03fdd4100e.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_119_jpg.rf.fde5580cb36ea48f7f826f757fd81295.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_11_jpg.rf.b054f3ff4b51f3edf4d184759201370e.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_120_jpg.rf.d683745f4dfb4331fc16852bfd06061f.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_121_jpg.rf.fa91d40ffe39334833102635768803dd.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_122_jpg.rf.0db12c42c508f1c9d16665e7051e6253.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_13_jpg.rf.21846d2397e011dc1b98fe7d5347c0cf.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_14_jpg.rf.bade53ef1b951a8611befeaf467f91f6.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_15_jpg.rf.13c0ce8726ce6def60f9b55b0237eed9.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_17_jpg.rf.dba1e33cba814e9986dd0720489b93cf.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_18_jpg.rf.b21de9baa75bf0f2bec76a1af0f68fea.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_19_jpg.rf.bd1005da0e70b55e009988718d43b506.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_1_jpg.rf.2660422d41437b2a28f2834fa42f9938.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_21_jpg.rf.af4f373fa3279792faaf1c40d1f2fb17.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_22_jpg.rf.1140112cce107f0c49ab9d4509db2eb0.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_23_jpg.rf.898719de123b3d994ca2869063c216da.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_24_jpg.rf.44a41da87c78cfbc52a7f824a41fbcc0.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_25_jpg.rf.3e2cdf6d74ed5165512f050d0be70e9b.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_26_jpg.rf.79628350c8a9cd4337211c476a25050b.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_27_jpg.rf.71403c4852a47c07fa74b3da4631570c.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_28_jpg.rf.461b37e264c28838abedeb74fec0c332.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_29_jpg.rf.8a1651f70502eca531d489a421ef3d98.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_2_jpg.rf.e13b04b95ab12b6720ef0ac583d45176.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_30_jpg.rf.49ec0b427b1065a7675fd5babb2cec97.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_31_jpg.rf.158dd67d365fef915991173115e161dd.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_32_jpg.rf.e77a5e573a168506fc4a168ba2fe5d9e.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_33_jpg.rf.aff100081c2a2a479375eded8f8d1d4c.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_38_jpg.rf.2dd22a8b2e09d30d3bd1e4abbe3235d7.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_39_jpg.rf.19a59ef1179cc5e4b738a68334fb1921.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_3_jpg.rf.c5798c91c4fd00236ac786a319dfa610.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_40_jpg.rf.49148699cf3299ded893a60556dda5d7.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_41_jpg.rf.461d0a547b9b152f41dbb70a38b23252.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_42_jpg.rf.91bfdfacbe92a4019bb8ff9bca2f128e.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_43_jpg.rf.79739b7a2671b9be1cf2f346214fae17.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_44_jpg.rf.7d0661047ad01f05d79fd4dbc0cebdca.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_45_jpg.rf.bb5390accd8a9c598c11f6ab7a712937.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_46_jpg.rf.c3661fe2f318b281b3c94813e7331176.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_47_jpg.rf.d0fd9b0b19546814d7e1558d1039b34f.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_48_jpg.rf.1d325dc6d2f0081f82ca23326bb7e85e.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_49_jpg.rf.6334a65ee7d9578523ba9962185ed6fd.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_4_jpg.rf.e036feeb6cd4a1810053a19b84f39080.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_50_jpg.rf.cf65a06ceea063b86366335cd78ac331.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_52_jpg.rf.9a9c63f17a5de5ebf42e33adc5de377c.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_54_jpg.rf.45ca9e057b35dad476822de7fd9a6bf5.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_55_jpg.rf.9e5a5ef80df0e29563266fff3859640d.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_56_jpg.rf.3613a1e6bda0a96524d7fab86d657c12.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_57_jpg.rf.cc9c8037fbf253a6d62bd0c4bf840019.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_58_jpg.rf.c9779fc47477ea0a83577835ec20edcf.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_59_jpg.rf.f48dad106ab723bd958e9d99ddf9acbb.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_5_jpg.rf.3051382a415395589cd5a8b35a860817.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_60_jpg.rf.477fe9725bf249d34b7744da1327b46d.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_61_jpg.rf.1e07ddebfff44b5af74481ffb44bb5df.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_62_jpg.rf.0ff5f10391e755ae6c472eb3147ac887.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_63_jpg.rf.fe681e6d390db970fc5941a116113f00.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_64_jpg.rf.d74f89efafcbf0d591db173d4d68b314.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_65_jpg.rf.0c1a17870aa6926d0d7785f30c80dba6.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_66_jpg.rf.d5185ef773e89449b3d447705d89f7e0.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_67_jpg.rf.d8fde8d3d5b3e5c677fca54ab87a72b1.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_68_jpg.rf.db5b3cc11a8b9178b44b240b72a65eda.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_69_jpg.rf.1bfc3ae1f3c47c8c2c3797973ed60780.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_6_jpg.rf.66f582abfeb7f115c51ed8cf9db67f35.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_71_jpg.rf.9f30057e066ce5ffc1b9b2d39220ced9.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_72_jpg.rf.c48a8e2dbc4e80bff586841ca0ab31f7.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_73_jpg.rf.a71c5db5f2aae6c6b4283f8e8bf298e8.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_75_jpg.rf.e2d280c64551d670cba779f86ca5f148.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_77_jpg.rf.8dace46d2fa7b5d4c66d23142334acc4.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_78_jpg.rf.c4136d4616f864713589798aa9a4e770.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_79_jpg.rf.25c8684b351dc606d14953aa3b3f68c0.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_80_jpg.rf.901379694800e3e2187a94efbc3eaac6.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_81_jpg.rf.eb11dba9ac7009dac41712144055ee69.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_82_jpg.rf.505ffdad465195aa1488e1b68a75b6c6.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_85_jpg.rf.3f89218d27d904e5e5ddc9ad640a7b59.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_86_jpg.rf.6a7bac92af3b643c0f6b95db248ab793.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_88_jpg.rf.f1ab64e5e0ebf2260bac7641f98797a4.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_89_jpg.rf.227b210b1043fc282d74be39813f64ea.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_8_jpg.rf.f0f93d64ae50a4fc469d42131e04ae23.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_90_jpg.rf.06f109389d732755a3bf2dd16998639e.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_92_jpg.rf.3c27e348b0d675b6a0402080918640dd.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_94_jpg.rf.f808a71d48cce2917d61ad42a98df108.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_95_jpg.rf.d80004270c5f35d4e024c907b35e3c0f.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_97_jpg.rf.af9d68aa2e92119e142e07332dde37ea.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_98_jpg.rf.d24a9d3ec2db8e191cecaed71f130e88.tiff only contains background. Skipping.
# Mask FG_tempegorengv2_9_jpg.rf.cccec23e29a1740d29fdcf55203605b0.tiff only contains background. Skipping.
# Found 656 valid image-mask pairs (with foreground objects).

# %%
if not image_mask_pairs_mc:
    raise ValueError("No image-mask pairs found. Check mask generation and paths.")

train_val_pairs_mc, test_pairs_mc = train_test_split(image_mask_pairs_mc, test_size=0.2, random_state=42)
train_pairs_mc, val_pairs_mc = train_test_split(train_val_pairs_mc, test_size=0.25, random_state=42)

train_image_paths_mc, train_mask_paths_mc = zip(*train_pairs_mc)
val_image_paths_mc, val_mask_paths_mc = zip(*val_pairs_mc)
test_image_paths_mc, test_mask_paths_mc = zip(*test_pairs_mc)

# %%
train_image_paths_mc = np.array(list(train_image_paths_mc), dtype=str)
train_mask_paths_mc = np.array(list(train_mask_paths_mc), dtype=str)
val_image_paths_mc = np.array(list(val_image_paths_mc), dtype=str)
val_mask_paths_mc = np.array(list(val_mask_paths_mc), dtype=str)
test_image_paths_mc = np.array(list(test_image_paths_mc), dtype=str)
test_mask_paths_mc = np.array(list(test_mask_paths_mc), dtype=str)

# %%
def load_image(image_path):
    image = cv2.imread(image_path.decode()) 
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, TARGET_SIZE)  
    image = image / 255.0  
    return image.astype(np.float32)

def load_mask_multiclass(mask_path_str_tensor):
    mask_path = mask_path_str_tensor.decode() 
    mask_hw = tiff.imread(mask_path) 
    
    mask_hw_resized = cv2.resize(mask_hw, (TARGET_SIZE[1], TARGET_SIZE[0]), interpolation=cv2.INTER_NEAREST)
    
    return mask_hw_resized.astype(np.int32)

# %%
crop_height_min = int(TARGET_SIZE[0] * 0.8)
crop_width_min = int(TARGET_SIZE[1] * 0.8)

# %% [markdown]
# ## Augmentasi

# %%
albumentations_transform_baseline = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=15, p=0.5, interpolation=cv2.INTER_NEAREST, border_mode=cv2.BORDER_CONSTANT, value=0, mask_value=0),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.HueSaturationValue(hue_shift_limit=5, sat_shift_limit=5, val_shift_limit=5, p=0.3),
    A.RandomCrop(width=crop_width_min, height=crop_height_min, p=0.5), 
    A.RandomResizedCrop(
                        size=TARGET_SIZE,
                        scale=(0.8, 1.0), ratio=(0.75, 1.33), 
                        interpolation=cv2.INTER_LINEAR, 
                        always_apply=False, p=0.5),
    A.MedianBlur(blur_limit=(3, 7), p=0.3),
    A.CLAHE(clip_limit=2.0, tile_grid_size=(8, 8), p=0.3),
    A.Resize(height=TARGET_SIZE[0], width=TARGET_SIZE[1], 
             interpolation=cv2.INTER_LINEAR, 
             always_apply=True) 
])
# Out:
# /tmp/ipykernel_2267911/3609351120.py:3: UserWarning: Argument(s) 'value, mask_value' are not valid for transform Rotate
#   A.Rotate(limit=15, p=0.5, interpolation=cv2.INTER_NEAREST, border_mode=cv2.BORDER_CONSTANT, value=0, mask_value=0),
# /tmp/ipykernel_2267911/3609351120.py:7: UserWarning: Argument(s) 'always_apply' are not valid for transform RandomResizedCrop
#   A.RandomResizedCrop(
# /tmp/ipykernel_2267911/3609351120.py:14: UserWarning: Argument(s) 'always_apply' are not valid for transform Resize
#   A.Resize(height=TARGET_SIZE[0], width=TARGET_SIZE[1],

# %% [markdown]
# ### Cutmix

# %%
def generate_cutmix_bounding_box(img_shape_tuple, lam_val): 
    img_h, img_w = img_shape_tuple[0], img_shape_tuple[1]
    
    cut_ratio = tf.sqrt(1. - lam_val) 
    cut_w = tf.cast(tf.cast(img_w, tf.float32) * cut_ratio, tf.int32)
    cut_h = tf.cast(tf.cast(img_h, tf.float32) * cut_ratio, tf.int32)

    cx = tf.random.uniform(shape=[], minval=0, maxval=img_w, dtype=tf.int32)
    cy = tf.random.uniform(shape=[], minval=0, maxval=img_h, dtype=tf.int32)

    bbx1 = tf.clip_by_value(cx - cut_w // 2, 0, img_w)
    bby1 = tf.clip_by_value(cy - cut_h // 2, 0, img_h)
    bbx2 = tf.clip_by_value(cx + cut_w // 2, 0, img_w)
    bby2 = tf.clip_by_value(cy + cut_h // 2, 0, img_h)
    
    actual_cut_w = bbx2 - bbx1
    actual_cut_h = bby2 - bby1
    
    new_lam = 1. - (tf.cast(actual_cut_w * actual_cut_h, tf.float32) / 
                    tf.cast(img_w * img_h, tf.float32))
    
    return bbx1, bby1, bbx2, bby2, new_lam

# %%
@tf.function
def cutmix_batch_tf_with_tensorarray(images_batch, masks_batch, alpha_py_float=1.0):
    batch_size = tf.shape(images_batch)[0]
    img_h_static = TARGET_SIZE[0]
    img_w_static = TARGET_SIZE[1]
    num_channels_img_static = 3

    is_mask_squeezed = (tf.rank(masks_batch) == 3)
    
    mixed_images_ta = tf.TensorArray(dtype=images_batch.dtype, size=batch_size, dynamic_size=False, element_shape=(img_h_static, img_w_static, num_channels_img_static))
    if is_mask_squeezed:
        mixed_masks_ta = tf.TensorArray(dtype=masks_batch.dtype, size=batch_size, dynamic_size=False, element_shape=(img_h_static, img_w_static))
    else:
        num_channels_mask_static = 1
        mixed_masks_ta = tf.TensorArray(dtype=masks_batch.dtype, size=batch_size, dynamic_size=False, element_shape=(img_h_static, img_w_static, num_channels_mask_static))


    indices = tf.random.shuffle(tf.range(batch_size))
    shuffled_images = tf.gather(images_batch, indices)
    shuffled_masks = tf.gather(masks_batch, indices)

    def _sample_beta_numpy_func(alpha_val_np):
        return np.float32(np.random.beta(alpha_val_np, alpha_val_np))

    for i in tf.range(batch_size):
        if tf.is_tensor(alpha_py_float) or alpha_py_float != 1.0 : 
            lam = tf.numpy_function(_sample_beta_numpy_func, 
                                    [tf.cast(alpha_py_float, tf.float64)], 
                                    tf.float32)
            lam.set_shape([]) 
        else: 
            lam = tf.random.uniform(shape=[], minval=0.0, maxval=1.0, dtype=tf.float32)


        img1 = images_batch[i]
        mask1 = masks_batch[i]
        img2 = shuffled_images[i]
        mask2 = shuffled_masks[i]

        bbx1, bby1, bbx2, bby2, _ = generate_cutmix_bounding_box(
            (img_h_static, img_w_static), 
            lam 
        )
        
        current_img_h_tensor = tf.shape(img1)[0] 
        current_img_w_tensor = tf.shape(img1)[1]

        x_coords = tf.range(current_img_w_tensor)
        y_coords = tf.range(current_img_h_tensor)
        X_grid, Y_grid = tf.meshgrid(x_coords, y_coords)
        
        cut_mask_2d_bool = (X_grid >= bbx1) & (X_grid < bbx2) & (Y_grid >= bby1) & (Y_grid < bby2)
        cut_mask_2d_float = tf.cast(cut_mask_2d_bool, dtype=img1.dtype)
        cut_mask_img_broadcast = cut_mask_2d_float[:, :, tf.newaxis]
        
        mask1_float = tf.cast(mask1, img1.dtype)
        mask2_float = tf.cast(mask2, img1.dtype)
        
        if is_mask_squeezed:
            mask1_float_expanded = mask1_float[..., tf.newaxis]
            mask2_float_expanded = mask2_float[..., tf.newaxis]
        else:
            mask1_float_expanded = mask1_float
            mask2_float_expanded = mask2_float

        mixed_img_i = img1 * (1. - cut_mask_img_broadcast) + img2 * cut_mask_img_broadcast
        mixed_mask_i_expanded_float = mask1_float_expanded * (1. - cut_mask_img_broadcast) + \
                                      mask2_float_expanded * cut_mask_img_broadcast
        
        mixed_images_ta = mixed_images_ta.write(i, mixed_img_i)
        
        if is_mask_squeezed:
            mixed_masks_ta = mixed_masks_ta.write(i, tf.cast(tf.squeeze(mixed_mask_i_expanded_float, axis=-1), masks_batch.dtype))
        else:
            mixed_masks_ta = mixed_masks_ta.write(i, tf.cast(mixed_mask_i_expanded_float, masks_batch.dtype))

    return mixed_images_ta.stack(), mixed_masks_ta.stack()

# %%
def apply_albumentations_multiclass(image_np, mask_np_hw):
    augmented = albumentations_transform_baseline(image=image_np, mask=mask_np_hw)
    aug_image = augmented['image'].astype(np.float32)
    aug_mask = augmented['mask'].astype(np.int32)
    
    if aug_image.shape[0] != TARGET_SIZE[0] or aug_image.shape[1] != TARGET_SIZE[1]:
        aug_image = cv2.resize(aug_image, (TARGET_SIZE[1], TARGET_SIZE[0]), interpolation=cv2.INTER_LINEAR)
    if aug_mask.shape[0] != TARGET_SIZE[0] or aug_mask.shape[1] != TARGET_SIZE[1]:
        aug_mask = cv2.resize(aug_mask, (TARGET_SIZE[1], TARGET_SIZE[0]), interpolation=cv2.INTER_NEAREST)
    return aug_image, aug_mask

# %%
@tf.function 
def tf_apply_albumentations(image, mask):
    aug_img, aug_mask = tf.numpy_function(
        apply_albumentations_multiclass, 
        [image, mask], 
        [tf.float32, tf.int32] 
    )
    aug_img.set_shape([TARGET_SIZE[0], TARGET_SIZE[1], 3])
    aug_mask.set_shape([TARGET_SIZE[0], TARGET_SIZE[1]])
    return aug_img, aug_mask

# %%
@tf.function
def tf_apply_cutmix_batch_for_partial(images_batch, masks_batch, fixed_alpha, fixed_prob):
    
    do_cutmix = tf.random.uniform(shape=[]) < fixed_prob
    
    mixed_images, mixed_masks = tf.cond(
        do_cutmix,
        lambda: cutmix_batch_tf_with_tensorarray(images_batch, masks_batch, alpha_py_float=fixed_alpha), 
        lambda: (images_batch, masks_batch)
    )
    return mixed_images, mixed_masks

# %% [markdown]
# ## Set up

# %%
def preprocess_multiclass(image_path_tensor, mask_path_tensor, augment=False):
    loaded_image_np = tf.numpy_function(load_image, [image_path_tensor], tf.float32)
    loaded_mask_np_hw = tf.numpy_function(load_mask_multiclass, [mask_path_tensor], tf.int32)

    image_for_aug = loaded_image_np
    mask_for_aug = loaded_mask_np_hw

    if augment:
        def _apply_aug_py(img_np_in, msk_np_in):
            aug_img_out, aug_msk_out = apply_albumentations_multiclass(img_np_in, msk_np_in)
            
            if aug_img_out.shape[0] != TARGET_SIZE[0] or aug_img_out.shape[1] != TARGET_SIZE[1] or aug_img_out.shape[2] != 3:
                print(f"ERROR in _apply_aug_py: Image shape mismatch! Expected {(TARGET_SIZE[0], TARGET_SIZE[1], 3)}, Got {aug_img_out.shape}")
            if aug_msk_out.shape[0] != TARGET_SIZE[0] or aug_msk_out.shape[1] != TARGET_SIZE[1]:
                print(f"ERROR in _apply_aug_py: Mask shape mismatch! Expected {(TARGET_SIZE[0], TARGET_SIZE[1])}, Got {aug_msk_out.shape}")

            return aug_img_out.astype(np.float32), aug_msk_out.astype(np.int32)

        image_after_aug, mask_after_aug = tf.numpy_function(
            _apply_aug_py,
            [image_for_aug, mask_for_aug],
            [tf.float32, tf.int32]
        )
        final_image = image_after_aug
        final_mask = mask_after_aug
    else:
        final_image = image_for_aug
        final_mask = mask_for_aug

    final_image.set_shape((TARGET_SIZE[0], TARGET_SIZE[1], 3))
    final_mask.set_shape((TARGET_SIZE[0], TARGET_SIZE[1]))

    return final_image, final_mask

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_image_paths_mc, train_mask_paths_mc))
train_dataset = train_dataset.shuffle(buffer_size=len(train_image_paths_mc))
train_dataset = train_dataset.map(lambda img_path, msk_path: preprocess_multiclass(img_path, msk_path, augment=True),num_parallel_calls=tf.data.AUTOTUNE)
# Out:
# I0000 00:00:1748871414.940991 2267911 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7525 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
train_dataset = train_dataset.batch(BATCH_SIZE)
CUTMIX_ALPHA_VALUE = 1.5 
CUTMIX_PROBABILITY_VALUE = 0.3
cutmix_map_fn = partial(tf_apply_cutmix_batch_for_partial, 
                        fixed_alpha=CUTMIX_ALPHA_VALUE, 
                        fixed_prob=CUTMIX_PROBABILITY_VALUE)
train_dataset = train_dataset.map(
    cutmix_map_fn, 
    num_parallel_calls=tf.data.AUTOTUNE
)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# train_dataset = tf.data.Dataset.from_tensor_slices((train_image_paths_mc, train_mask_paths_mc))
# train_dataset = train_dataset.map(lambda img_p, msk_p: preprocess_multiclass(img_p, msk_p, augment=True),
#                                         num_parallel_calls=tf.data.AUTOTUNE)
# train_dataset = train_dataset.shuffle(buffer_size=len(train_image_paths_mc)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_image_paths_mc, val_mask_paths_mc))
val_dataset = val_dataset.map(lambda img_p, msk_p: preprocess_multiclass(img_p, msk_p, augment=False),
                                      num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_image_paths_mc, test_mask_paths_mc))
test_dataset = test_dataset.map(lambda img_p, msk_p: preprocess_multiclass(img_p, msk_p, augment=False),
                                       num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
def show_image_and_masks_with_info(image, mask, title_prefix="Sample"):
    print(f"\n--- {title_prefix} Sample ---")
    print(f"Image Shape: {image.shape}, Image dtype: {image.dtype}")
    print(f"Mask Shape: {mask.shape}, Mask dtype: {mask.dtype}")

    num_channels_mask = mask.shape[-1] if mask.ndim == 3 else 1

    if num_channels_mask > 1 and mask.ndim == 3: 
        print("Mask Type: Potentially Multi-channel (could be for multi-label or one-hot multi-class)")
        for i in range(num_channels_mask):
            channel_mask = mask[..., i]
            print(f"  Channel {i} (Class {i+1}): min={np.min(channel_mask)}, max={np.max(channel_mask)}, unique_values={np.unique(channel_mask[:5,:5])[:5]}...") 
    elif mask.ndim == 2 or (mask.ndim == 3 and num_channels_mask == 1): 
        if mask.ndim == 3: 
            mask_to_analyze = mask[..., 0]
        else: 
            mask_to_analyze = mask
        
        unique_values = np.unique(mask_to_analyze)
        print(f"Mask Type: Single-channel (likely Multi-Class with class IDs)")
        print(f"  Unique values in mask: {unique_values}")
    else:
        print("Mask Type: Unknown or unexpected shape.")

    plt.figure(figsize=(3 * (num_channels_mask + 1), 4))
    
    plt.subplot(1, num_channels_mask + 1, 1)
    plt.imshow(image)
    plt.title(f"{title_prefix} Image")
    plt.axis("off")

    if mask.ndim == 3 and num_channels_mask > 1:
        for i in range(num_channels_mask):
            plt.subplot(1, num_channels_mask + 1, i + 2)
            plt.imshow(mask[..., i], cmap='gray') 
            plt.title(f"Mask Ch. {i}")
            plt.axis("off")
    elif mask.ndim == 2 or (mask.ndim == 3 and num_channels_mask == 1):
        mask_to_show = mask[..., 0] if mask.ndim == 3 else mask
        plt.subplot(1, num_channels_mask + 1, 2) 
        num_expected_classes_if_multiclass = len(np.unique(mask_to_show)) 
        plt.imshow(mask_to_show, cmap='tab20', vmin=0, vmax=max(1, num_expected_classes_if_multiclass -1))
        plt.title(f"Mask (Class IDs)")
        plt.axis("off")


    plt.tight_layout()
    plt.show()

# %%
# print("Analyzing Training Data:")
# try:
#     train_batch = next(iter(train_dataset.take(1))) 
#     train_imgs_tf, train_masks_tf = train_batch
#     train_imgs_np = train_imgs_tf.numpy()
#     train_masks_np = train_masks_tf.numpy()

#     for i in range(min(5, train_imgs_np.shape[0])): 
#         show_image_and_masks_with_info(train_imgs_np[i], train_masks_np[i], title_prefix=f"Train Sample {i+1}")
# except Exception as e:
#     print(f"Error processing training data: {e}")
#     print("Pastikan train_dataset adalah objek tf.data.Dataset yang sudah di-batch.")

# print("\nAnalyzing Test Data (atau Validation Data):")
# try:
#     test_batch = next(iter(test_dataset.take(1))) 
#     test_imgs_tf, test_masks_tf = test_batch
#     test_imgs_np = test_imgs_tf.numpy()
#     test_masks_np = test_masks_tf.numpy()

#     for i in range(min(5, test_imgs_np.shape[0])): 
#         show_image_and_masks_with_info(test_imgs_np[i], test_masks_np[i], title_prefix=f"Test/Val Sample {i+1}")
# except Exception as e:
#     print(f"Error processing test/validation data: {e}")
#     print("Pastikan test_dataset adalah objek tf.data.Dataset yang sudah di-batch.")

# %%
for sample_images, sample_masks_hw in train_dataset.take(1): 
    print(f"Sample images batch shape: {sample_images.shape}, dtype: {sample_images.dtype}")
    print(f"Sample masks_hw batch shape: {sample_masks_hw.shape}, dtype: {sample_masks_hw.dtype}") 
    mask_to_check = sample_masks_hw[0].numpy()
    unique_vals_in_mask = np.unique(mask_to_check)
    print(f"Mask unique values in first sample: {unique_vals_in_mask}") 
    if True: 
        plt.figure(figsize=(8, 4))
        plt.subplot(1, 2, 1)
        plt.imshow(sample_images[0].numpy())
        plt.title("Sample Image")
        plt.axis("off")
        plt.subplot(1, 2, 2)
        plt.imshow(mask_to_check, cmap='tab10', vmin=0, vmax=max(1, NUM_MODEL_CLASSES -1))
        plt.title(f"Sample Mask (Class IDs)\nUnique: {unique_vals_in_mask}")
        plt.axis("off")
        plt.show()
    break
# Out:
# Sample images batch shape: (8, 320, 320, 3), dtype: <dtype: 'float32'>
# Sample masks_hw batch shape: (8, 320, 320), dtype: <dtype: 'int32'>
# Mask unique values in first sample: [0 3]

# %% [markdown]
# # Model

# %% [markdown]
# ## Encoder

# %% [markdown]
# ### CBAM

# %%
class GlobalChannelMeanPool(layers.Layer):
    def __init__(self, **kwargs):
        super(GlobalChannelMeanPool, self).__init__(**kwargs)

    def call(self, inputs):
        return K.mean(inputs, axis=3, keepdims=True)

    def compute_output_shape(self, input_shape):
        return tf.TensorShape([input_shape[0], input_shape[1], input_shape[2], 1])

class GlobalChannelMaxPool(layers.Layer):
    def __init__(self, **kwargs):
        super(GlobalChannelMaxPool, self).__init__(**kwargs)

    def call(self, inputs):
        return K.max(inputs, axis=3, keepdims=True)

    def compute_output_shape(self, input_shape):
        return tf.TensorShape([input_shape[0], input_shape[1], input_shape[2], 1])

# %%
# Modul Channel Attention (CAM) dari CBAM
def channel_attention_module(x, ratio=8, name_prefix=""):
    
    batch, height, width, channels = K.int_shape(x) 
    
    # Squeeze
    avg_pool = GlobalAveragePooling2D(name=f"{name_prefix}_cam_avg_pool")(x)
    max_pool = GlobalMaxPooling2D(name=f"{name_prefix}_cam_max_pool")(x)
    
    # Reshape untuk Dense layer
    avg_pool = Reshape((1, 1, channels), name=f"{name_prefix}_cam_avg_reshape")(avg_pool)
    max_pool = Reshape((1, 1, channels), name=f"{name_prefix}_cam_max_reshape")(max_pool)
    
    # Shared MLP
    # Layer Dense pertama (reduksi)
    dense_shared_1 = Dense(channels // ratio, activation='relu', use_bias=False, name=f"{name_prefix}_cam_mlp_shared_1")
    mlp_avg_1 = dense_shared_1(avg_pool)
    mlp_max_1 = dense_shared_1(max_pool)
    
    # Layer Dense kedua (ekspansi)
    dense_shared_2 = Dense(channels, use_bias=False, name=f"{name_prefix}_cam_mlp_shared_2")
    mlp_avg_2 = dense_shared_2(mlp_avg_1)
    mlp_max_2 = dense_shared_2(mlp_max_1)
    
    # Excitation
    combined_features = Add(name=f"{name_prefix}_cam_add")([mlp_avg_2, mlp_max_2])
    channel_attention_weights = Activation('sigmoid', name=f"{name_prefix}_cam_sigmoid")(combined_features)
    
    # Kalikan bobot perhatian dengan fitur input
    refined_feature = Multiply(name=f"{name_prefix}_cam_multiply")([x, channel_attention_weights])
    return refined_feature

# %%
# Modul Spatial Attention (SAM) dari CBAM
def spatial_attention_module(x, kernel_size=7, name_prefix=""):
    input_shape_tensor = x.shape

    def pooling_output_shape(input_shape_arg): 
        current_input_shape = input_shape_arg 
        if not isinstance(current_input_shape, tf.TensorShape):
            try:
                current_input_shape = tf.TensorShape(current_input_shape)
            except:
                if hasattr(current_input_shape, '__len__') and len(current_input_shape) > 2:
                     return tuple([None] * (len(current_input_shape) - 2) + [1])
                else: 
                    return (None, None, 1)
    
        if current_input_shape.rank == 4: 
            return (current_input_shape[1], current_input_shape[2], 1)
        elif current_input_shape.rank == 3: 
            return (current_input_shape[0], current_input_shape[1], 1)
        else: 
            return (None, None, 1)

    avg_pool = GlobalChannelMeanPool(name=f"{name_prefix}_sam_avg_pool_custom")(x)
    max_pool = GlobalChannelMaxPool(name=f"{name_prefix}_sam_max_pool_custom")(x)
    
    print(f"Shape avg_pool sebelum concat ({name_prefix}): {avg_pool.shape}")
    print(f"Shape max_pool sebelum concat ({name_prefix}): {max_pool.shape}")
    
    concat_features = Concatenate(axis=3, name=f"{name_prefix}_sam_concat")([avg_pool, max_pool])
    
    spatial_attention_map = Conv2D(1, kernel_size, padding='same', activation='sigmoid', 
                                   kernel_initializer='he_normal', use_bias=False, 
                                   name=f"{name_prefix}_sam_conv")(concat_features) 
    
    refined_feature = Multiply(name=f"{name_prefix}_sam_multiply")([x, spatial_attention_map])
    return refined_feature

# %%
# CBAM Block: Channel Attention Module diikuti Spatial Attention Module
def cbam_block(x, ratio=8, kernel_size=7, name=None):
    base_name = name if name else f"cbam_{K.get_uid('cbam_')}"

    x_channel_refined = channel_attention_module(x, ratio=ratio, name_prefix=f"{base_name}_channel")
    x_spatial_refined = spatial_attention_module(x_channel_refined, kernel_size=kernel_size, name_prefix=f"{base_name}_spatial")
    return x_spatial_refined

# %%
def transition_layer(x, filters, name="transition_layer"):
    x = layers.Conv2D(filters, (1, 1), padding='same', activation='relu', name=name)(x)
    x = layers.AveragePooling2D((2, 2), strides=2, padding='same')(x)
    return x

# %% [markdown]
# ### Encoder Block

# %%
def encoder_os32_10x10(input_tensor, dense_blocks_count=7, cbam_kernel_size=9, cbam_ratio=16):
    skips = []
    
    # Initial Conv + Pool (2x downsampling)
    x = layers.Conv2D(64, (7, 7), strides=2, padding='same', activation='relu', name='enc_os32_conv1')(input_tensor) # 320->160
    x = layers.BatchNormalization(name='enc_os32_bn1')(x)
    skips.append(x) # Skip 0: 160x160

    x = layers.MaxPooling2D((3, 3), strides=2, padding='same', name='enc_os32_pool1')(x) # 160->80
    skips.append(x) # Skip 1: 80x80

    # Tahap 1 (input 80x80 -> output 40x40)
    x = dense_block(x, filters=64, blocks=dense_blocks_count, name="enc_os32_dense_block1") 
    x = transition_layer(x, x.shape[-1] // 2, name="enc_os32_transition1") 
    x = cbam_block(x, ratio=cbam_ratio, kernel_size=cbam_kernel_size, name="enc_os32_cbam1")
    skips.append(x) # Skip 2: 40x40

    # Tahap 2 (input 40x40 -> output 20x20)
    x = dense_block(x, filters=128, blocks=dense_blocks_count, name="enc_os32_dense_block2")
    x = transition_layer(x, x.shape[-1] // 2, name="enc_os32_transition2") 
    x = cbam_block(x, ratio=cbam_ratio, kernel_size=cbam_kernel_size, name="enc_os32_cbam2")
    skips.append(x) # Skip 3: 20x20

    # Tahap 3 (input 20x20 -> output 10x10) (Bottleneck)
    x = dense_block(x, filters=256, blocks=dense_blocks_count, name="enc_os32_dense_block3_bottleneck_in")
    x = transition_layer(x, x.shape[-1] // 2, name="enc_os32_transition3_bottleneck_out") 
    x = cbam_block(x, ratio=cbam_ratio, kernel_size=cbam_kernel_size, name="enc_os32_cbam3_bottleneck_final")
    # 'x' = bottleneck 10x10
    
    # skips = [160, 80, 40, 20]
    print("Encoder OS32 (10x10) - Skip Shapes for Decoder:")
    for i_s, s_item in enumerate(skips):
        print(f"Skip {i_s}: {s_item.shape}")
    print(f"Encoder OS32 (10x10) - Bottleneck Shape: {x.shape}")
    
    return x, skips

# %% [markdown]
# ## Decoder

# %%
def attention_gate(x, g, inter_channels):
    theta_x = Conv2D(inter_channels, (1,1))(x)
    phi_g = Conv2D(inter_channels, (1,1))(g)
    add = Activation('relu')(Add()([theta_x, phi_g]))
    psi = Conv2D(1, (1,1), activation='sigmoid')(add)
    return Multiply()([x, psi])

# %%
def crop_to_match(tensors):
    up, skip = tensors
    uh, uw = tf.shape(up)[1], tf.shape(up)[2]
    sh, sw = tf.shape(skip)[1], tf.shape(skip)[2]
    dh, dw = sh - uh, sw - uw
    top, left = dh // 2, dw // 2
    return skip[:, top:top+uh, left:left+uw, :]

# %%
def se_block_decoder(inputs, ratio=8, name=None):
    filters = inputs.shape[-1]
    se = layers.GlobalAveragePooling2D()(inputs)  
    se = layers.Dense(filters // ratio, activation='relu')(se)
    se = layers.Dense(filters, activation='sigmoid')(se)
    se = layers.Reshape((1, 1, filters))(se)      
    return layers.Multiply(name=name)([inputs, se])

# %% [markdown]
# ### Decoder block

# %%
def decoder_os32_10x10(bottleneck_aspp_input, skips_from_encoder, num_classes, cbam_kernel_size=5, cbam_ratio=8):
    x = bottleneck_aspp_input 

    # Filter untuk 4 tahap upsampling di loop
    decoder_filter_sizes = [256, 128, 64, 32] 

    for i, f_decoder in enumerate(decoder_filter_sizes):
        x = layers.Conv2DTranspose(f_decoder, (3, 3), strides=2, padding='same', activation='relu', name=f"dec_os32_upconv_{i+1}")(x)
        
        skip_index = len(skips_from_encoder) - 1 - i
        skip_connection = skips_from_encoder[skip_index]
        
        skip_connection = Lambda(crop_to_match, name=f"dec_os32_crop_skip_{i+1}")([x, skip_connection])

        att_skip = attention_gate(skip_connection, x, inter_channels=f_decoder // 2)
        x = layers.Concatenate(name=f"dec_os32_concat_skip_{i+1}")([x, att_skip])
        x = cbam_block(x, ratio=cbam_ratio, kernel_size=cbam_kernel_size, name=f"dec_os32_cbam_{i+1}")
        x = layers.Conv2D(f_decoder, (3, 3), padding='same', activation='relu', name=f"dec_os32_conv_after_cbam_{i+1}")(x)
        x = layers.SpatialDropout2D(0.25)(x)

    x = layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation='relu', name="dec_os32_final_upsample_to_target")(x) 
    return x

# %% [markdown]
# ## Construct Model

# %%
def aspp_module(inputs, num_filters, rates=[6, 12, 18], name_prefix="aspp"):
    dims = K.int_shape(inputs) 
    
    conv_1x1 = layers.Conv2D(num_filters, (1, 1), padding="same", activation="relu", 
                             kernel_regularizer=regularizers.l2(1e-4),
                             name=f"{name_prefix}_conv1x1")(inputs)

    # Atrous Convolutions
    atrous_convs = [conv_1x1] 
    for rate in rates:
        conv_rate = layers.Conv2D(num_filters, (3, 3), padding="same", activation="relu", 
                                  dilation_rate=rate, 
                                  kernel_regularizer=regularizers.l2(1e-4),
                                  name=f"{name_prefix}_dconv_rate{rate}")(inputs)
        atrous_convs.append(conv_rate)

    # Image Pooling
    if dims[1] is not None and dims[2] is not None:
        pool_size = (dims[1], dims[2]) 
        img_pool = layers.AveragePooling2D(pool_size=pool_size, name=f"{name_prefix}_img_pool")(inputs)
        img_pool_conv = layers.Conv2D(num_filters, (1, 1), padding="same", activation="relu",
                                      kernel_regularizer=regularizers.l2(1e-4),
                                      name=f"{name_prefix}_img_pool_conv")(img_pool)
     
        img_pool_upsampled = layers.UpSampling2D(size=(dims[1], dims[2]), interpolation='bilinear', name=f"{name_prefix}_img_pool_upsample_tf_lt_2.4")(img_pool_conv)

        atrous_convs.append(img_pool_upsampled)
    else:
        print("Warning: ASPP input dimensions are None, skipping image pooling branch upsampling.")
    concat = layers.Concatenate(axis=-1, name=f"{name_prefix}_concat")(atrous_convs)
    
    output = layers.Conv2D(num_filters, (1, 1), padding="same", activation="relu",
                           kernel_regularizer=regularizers.l2(1e-4),
                           name=f"{name_prefix}_output_conv")(concat)
    output = layers.SpatialDropout2D(0.25, name=f"{name_prefix}_dropout")(output)
    return output

# %%
def build_unet_densenet_encoder(input_shape=(TARGET_SIZE[0], TARGET_SIZE[1], 3), num_classes=NUM_MODEL_CLASSES):
    inputs = Input(shape=input_shape)

    encoder_output, skips = encoder_os32_10x10(inputs)
    bottleneck_aspp = aspp_module(encoder_output, num_filters=256, rates=[3, 6, 9], name_prefix="aspp_bottleneck")
    x = decoder_os32_10x10(bottleneck_aspp, skips, num_classes)

    x = layers.Conv2D(64, (3,3), padding='same', activation='relu', name="decoder_refine_1")(x)

    x = layers.BatchNormalization(name="decoder_refine_bn_1")(x)

    x = layers.Conv2D(64, (3,3), padding='same', activation='relu', name="decoder_refine_2")(x)

    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', name="output_layer")(x)


    return models.Model(inputs, outputs, name="DenseNet_Encoder_UNet")

# %% [markdown]
# ## Build Model

# %%
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

# %%
# COMBINE LOSS

def dice_loss_sparse_multiclass_from_probs(y_true_sparse, y_pred_prob, smooth=1e-6): 
    y_true_one_hot = tf.one_hot(tf.cast(y_true_sparse, tf.int32), depth=NUM_MODEL_CLASSES, axis=-1)
    
    axes_to_reduce = [1, 2] 
    intersection = tf.reduce_sum(y_true_one_hot * y_pred_prob, axis=axes_to_reduce) 
    sum_true = tf.reduce_sum(y_true_one_hot, axis=axes_to_reduce) 
    sum_pred = tf.reduce_sum(y_pred_prob, axis=axes_to_reduce) 
    
    dice_per_sample_per_class = (2. * intersection + smooth) / (sum_true + sum_pred + smooth) 
    
    mean_dice_per_class = tf.reduce_mean(dice_per_sample_per_class, axis=0) 
    mean_dice_overall = tf.reduce_mean(mean_dice_per_class) 
    
    return 1 - mean_dice_overall

def combined_loss_multiclass_sparse_from_probs(alpha=0.7, beta=0.3):
    scc_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

    def loss(y_true_sparse, y_pred_prob): 
        scc = scc_loss_fn(y_true_sparse, y_pred_prob)
        dice = dice_loss_sparse_multiclass_from_probs(y_true_sparse, y_pred_prob)
        return alpha * scc + beta * dice
    return loss

# %%
class MeanIoUAdapted(tf.keras.metrics.Metric):
    def __init__(self, num_classes_metric, name='mean_iou_adapted', **kwargs):
        super(MeanIoUAdapted, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes_metric
        self.total_cm = self.add_weight(
            name='total_confusion_matrix',
            shape=(self.num_classes, self.num_classes),
            initializer='zeros',
            dtype=tf.int64
        )

    def update_state(self, y_true_sparse, y_pred_input, sample_weight=None): 
        
        y_pred_labels = tf.argmax(y_pred_input, axis=-1, output_type=tf.int32)
        y_true_labels = tf.cast(y_true_sparse, dtype=tf.int32)

        y_true_flat = tf.reshape(y_true_labels, [-1])
        y_pred_flat = tf.reshape(y_pred_labels, [-1])

        current_cm = tf.math.confusion_matrix(
            labels=y_true_flat,
            predictions=y_pred_flat,
            num_classes=self.num_classes,
            dtype=self.total_cm.dtype
        )
        self.total_cm.assign_add(tf.cast(current_cm, self.total_cm.dtype))

    def result(self):
        sum_over_row = tf.cast(tf.reduce_sum(self.total_cm, axis=0), dtype=tf.float32)
        sum_over_col = tf.cast(tf.reduce_sum(self.total_cm, axis=1), dtype=tf.float32)
        true_positives = tf.cast(tf.linalg.tensor_diag_part(self.total_cm), dtype=tf.float32)

        denominator = sum_over_row + sum_over_col - true_positives
        iou_per_class = true_positives / (denominator + tf.keras.backend.epsilon())
        
        valid_iou_mask = tf.math.greater(denominator, 0.0)
        iou_per_class_valid = tf.where(valid_iou_mask, iou_per_class, tf.zeros_like(iou_per_class))
        
        num_valid_classes = tf.reduce_sum(tf.cast(valid_iou_mask, tf.float32))
        mean_iou = tf.reduce_sum(iou_per_class_valid) / (num_valid_classes + tf.keras.backend.epsilon())
        return mean_iou

    def reset_states(self):
        self.total_cm.assign(tf.zeros_like(self.total_cm))

# %%
model = build_unet_densenet_encoder(
    input_shape=(TARGET_SIZE[0], TARGET_SIZE[1], 3),
    num_classes=NUM_MODEL_CLASSES
)
model.summary()
# Out:
# Shape avg_pool sebelum concat (enc_os32_cbam1_spatial): (None, 40, 40, 1)
# Shape max_pool sebelum concat (enc_os32_cbam1_spatial): (None, 40, 40, 1)
# Shape avg_pool sebelum concat (enc_os32_cbam2_spatial): (None, 20, 20, 1)
# Shape max_pool sebelum concat (enc_os32_cbam2_spatial): (None, 20, 20, 1)
# Shape avg_pool sebelum concat (enc_os32_cbam3_bottleneck_final_spatial): (None, 10, 10, 1)
# Shape max_pool sebelum concat (enc_os32_cbam3_bottleneck_final_spatial): (None, 10, 10, 1)
# Encoder OS32 (10x10) - Skip Shapes for Decoder:
# Skip 0: (None, 160, 160, 64)
# Skip 1: (None, 80, 80, 64)
# Skip 2: (None, 40, 40, 256)
# Skip 3: (None, 20, 20, 576)
# Encoder OS32 (10x10) - Bottleneck Shape: (None, 10, 10, 1184)
# Shape avg_pool sebelum concat (dec_os32_cbam_1_spatial): (None, 20, 20, 1)
# Shape max_pool sebelum concat (dec_os32_cbam_1_spatial): (None, 20, 20, 1)
# Shape avg_pool sebelum concat (dec_os32_cbam_2_spatial): (None, 40, 40, 1)
# Shape max_pool sebelum concat (dec_os32_cbam_2_spatial): (None, 40, 40, 1)
# Shape avg_pool sebelum concat (dec_os32_cbam_3_spatial): (None, 80, 80, 1)
# Shape max_pool sebelum concat (dec_os32_cbam_3_spatial): (None, 80, 80, 1)
# Shape avg_pool sebelum concat (dec_os32_cbam_4_spatial): (None, 160, 160, 1)
# Shape max_pool sebelum concat (dec_os32_cbam_4_spatial): (None, 160, 160, 1)
# Model: "DenseNet_Encoder_UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 320, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_conv1      │ (None, 160, 160,  │      9,472 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_bn1        │ (None, 160, 160,  │        256 │ enc_os32_conv1[0… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_pool1      │ (None, 80, 80,    │          0 │ enc_os32_bn1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │        256 │ enc_os32_pool1[0… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      1,040 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │         64 │ dropout[0][0]     │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      9,280 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_pool1[0… │
# │ (Concatenate)       │ 128)              │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │        512 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      2,064 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │         64 │ dropout_2[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      9,280 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 192)              │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │        768 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      3,088 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │         64 │ dropout_4[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      9,280 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 256)              │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      1,024 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      4,112 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │         64 │ dropout_6[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      9,280 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 320)              │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      1,280 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      5,136 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │         64 │ dropout_8[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      9,280 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 384)              │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      1,536 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      6,160 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │         64 │ dropout_10[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      9,280 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 448)              │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      1,792 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      7,184 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │         64 │ dropout_12[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │      9,280 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 80, 80,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 512)              │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_transitio… │ (None, 80, 80,    │    131,328 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 40, 40,    │          0 │ enc_os32_transit… │
# │ (AveragePooling2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 256)       │          0 │ average_pooling2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 256)       │          0 │ average_pooling2… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 1, 1, 256) │          0 │ enc_os32_cbam1_c… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 1, 1, 256) │          0 │ enc_os32_cbam1_c… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 1, 1, 16)  │      4,096 │ enc_os32_cbam1_c… │
# │ (Dense)             │                   │            │ enc_os32_cbam1_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 1, 1, 256) │      4,096 │ enc_os32_cbam1_c… │
# │ (Dense)             │                   │            │ enc_os32_cbam1_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 1, 1, 256) │          0 │ enc_os32_cbam1_c… │
# │ (Add)               │                   │            │ enc_os32_cbam1_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 1, 1, 256) │          0 │ enc_os32_cbam1_c… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_cha… │ (None, 40, 40,    │          0 │ average_pooling2… │
# │ (Multiply)          │ 256)              │            │ enc_os32_cbam1_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_spa… │ (None, 40, 40, 1) │          0 │ enc_os32_cbam1_c… │
# │ (GlobalChannelMean… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_spa… │ (None, 40, 40, 1) │          0 │ enc_os32_cbam1_c… │
# │ (GlobalChannelMaxP… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_spa… │ (None, 40, 40, 2) │          0 │ enc_os32_cbam1_s… │
# │ (Concatenate)       │                   │            │ enc_os32_cbam1_s… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_spa… │ (None, 40, 40, 1) │        162 │ enc_os32_cbam1_s… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam1_spa… │ (None, 40, 40,    │          0 │ enc_os32_cbam1_c… │
# │ (Multiply)          │ 256)              │            │ enc_os32_cbam1_s… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │      1,024 │ enc_os32_cbam1_s… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │      8,224 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │        128 │ dropout_14[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     36,992 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_cbam1_s… │
# │ (Concatenate)       │ 384)              │            │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │      1,536 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     12,320 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │        128 │ dropout_16[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     36,992 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 512)              │            │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │      2,048 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     16,416 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │        128 │ dropout_18[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     36,992 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 640)              │            │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │      2,560 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     20,512 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │        128 │ dropout_20[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     36,992 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 768)              │            │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │      3,072 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     24,608 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │        128 │ dropout_22[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     36,992 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 896)              │            │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │      3,584 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 896)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 896)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     28,704 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │        128 │ dropout_24[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     36,992 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 1024)             │            │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │      4,096 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     32,800 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │        128 │ dropout_26[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │     36,992 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 40, 40,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 1152)             │            │ dropout_27[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_transitio… │ (None, 40, 40,    │    664,128 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 20, 20,    │          0 │ enc_os32_transit… │
# │ (AveragePooling2D)  │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 576)       │          0 │ average_pooling2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 576)       │          0 │ average_pooling2… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 1, 1, 576) │          0 │ enc_os32_cbam2_c… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 1, 1, 576) │          0 │ enc_os32_cbam2_c… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 1, 1, 36)  │     20,736 │ enc_os32_cbam2_c… │
# │ (Dense)             │                   │            │ enc_os32_cbam2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 1, 1, 576) │     20,736 │ enc_os32_cbam2_c… │
# │ (Dense)             │                   │            │ enc_os32_cbam2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 1, 1, 576) │          0 │ enc_os32_cbam2_c… │
# │ (Add)               │                   │            │ enc_os32_cbam2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 1, 1, 576) │          0 │ enc_os32_cbam2_c… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_cha… │ (None, 20, 20,    │          0 │ average_pooling2… │
# │ (Multiply)          │ 576)              │            │ enc_os32_cbam2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_spa… │ (None, 20, 20, 1) │          0 │ enc_os32_cbam2_c… │
# │ (GlobalChannelMean… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_spa… │ (None, 20, 20, 1) │          0 │ enc_os32_cbam2_c… │
# │ (GlobalChannelMaxP… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_spa… │ (None, 20, 20, 2) │          0 │ enc_os32_cbam2_s… │
# │ (Concatenate)       │                   │            │ enc_os32_cbam2_s… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_spa… │ (None, 20, 20, 1) │        162 │ enc_os32_cbam2_s… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_cbam2_spa… │ (None, 20, 20,    │          0 │ enc_os32_cbam2_c… │
# │ (Multiply)          │ 576)              │            │ enc_os32_cbam2_s… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │      2,304 │ enc_os32_cbam2_s… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │     36,928 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │        256 │ dropout_28[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │    147,712 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_cbam2_s… │
# │ (Concatenate)       │ 832)              │            │ dropout_29[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │      3,328 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 832)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 832)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │     53,312 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │        256 │ dropout_30[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │    147,712 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 1088)             │            │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │      4,352 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 1088)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 1088)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │     69,696 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │        256 │ dropout_32[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │    147,712 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 1344)             │            │ dropout_33[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │      5,376 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 1344)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 1344)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │     86,080 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │        256 │ dropout_34[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │    147,712 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Concatenate)       │ 1600)             │            │ dropout_35[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │      6,400 │ enc_os32_dense_b… │
# │ (BatchNormalizatio… │ 1600)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │          0 │ enc_os32_dense_b… │
# │ (Activation)        │ 1600)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_os32_dense_blo… │ (None, 20, 20,    │    102,464 │ enc_os32_dense_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
# │ dec_os32_cbam_2_ch… │ (None, 1, 1, 384) │          0 │ dec_os32_cbam_2_… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_ch… │ (None, 1, 1, 384) │          0 │ dec_os32_cbam_2_… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_ch… │ (None, 1, 1, 48)  │     18,432 │ dec_os32_cbam_2_… │
# │ (Dense)             │                   │            │ dec_os32_cbam_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_ch… │ (None, 1, 1, 384) │     18,432 │ dec_os32_cbam_2_… │
# │ (Dense)             │                   │            │ dec_os32_cbam_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_ch… │ (None, 1, 1, 384) │          0 │ dec_os32_cbam_2_… │
# │ (Add)               │                   │            │ dec_os32_cbam_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_ch… │ (None, 1, 1, 384) │          0 │ dec_os32_cbam_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_ch… │ (None, 40, 40,    │          0 │ dec_os32_concat_… │
# │ (Multiply)          │ 384)              │            │ dec_os32_cbam_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_sp… │ (None, 40, 40, 1) │          0 │ dec_os32_cbam_2_… │
# │ (GlobalChannelMean… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_sp… │ (None, 40, 40, 1) │          0 │ dec_os32_cbam_2_… │
# │ (GlobalChannelMaxP… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_sp… │ (None, 40, 40, 2) │          0 │ dec_os32_cbam_2_… │
# │ (Concatenate)       │                   │            │ dec_os32_cbam_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_sp… │ (None, 40, 40, 1) │         50 │ dec_os32_cbam_2_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_2_sp… │ (None, 40, 40,    │          0 │ dec_os32_cbam_2_… │
# │ (Multiply)          │ 384)              │            │ dec_os32_cbam_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_conv_afte… │ (None, 40, 40,    │    442,496 │ dec_os32_cbam_2_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_1 │ (None, 40, 40,    │          0 │ dec_os32_conv_af… │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_upconv_3   │ (None, 80, 80,    │     73,792 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_crop_skip… │ (None, 80, 80,    │          0 │ dec_os32_upconv_… │
# │ (Lambda)            │ 64)               │            │ enc_os32_pool1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 80, 80,    │      2,080 │ dec_os32_crop_sk… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 80, 80,    │      2,080 │ dec_os32_upconv_… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 80, 80,    │          0 │ conv2d_6[0][0],   │
# │                     │ 32)               │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 80, 80,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 80, 80, 1) │         33 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 80, 80,    │          0 │ dec_os32_crop_sk… │
# │ (Multiply)          │ 64)               │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_concat_sk… │ (None, 80, 80,    │          0 │ dec_os32_upconv_… │
# │ (Concatenate)       │ 128)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 128)       │          0 │ dec_os32_concat_… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 128)       │          0 │ dec_os32_concat_… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 1, 1, 128) │          0 │ dec_os32_cbam_3_… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 1, 1, 128) │          0 │ dec_os32_cbam_3_… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 1, 1, 16)  │      2,048 │ dec_os32_cbam_3_… │
# │ (Dense)             │                   │            │ dec_os32_cbam_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 1, 1, 128) │      2,048 │ dec_os32_cbam_3_… │
# │ (Dense)             │                   │            │ dec_os32_cbam_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 1, 1, 128) │          0 │ dec_os32_cbam_3_… │
# │ (Add)               │                   │            │ dec_os32_cbam_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 1, 1, 128) │          0 │ dec_os32_cbam_3_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_ch… │ (None, 80, 80,    │          0 │ dec_os32_concat_… │
# │ (Multiply)          │ 128)              │            │ dec_os32_cbam_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_sp… │ (None, 80, 80, 1) │          0 │ dec_os32_cbam_3_… │
# │ (GlobalChannelMean… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_sp… │ (None, 80, 80, 1) │          0 │ dec_os32_cbam_3_… │
# │ (GlobalChannelMaxP… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_sp… │ (None, 80, 80, 2) │          0 │ dec_os32_cbam_3_… │
# │ (Concatenate)       │                   │            │ dec_os32_cbam_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_sp… │ (None, 80, 80, 1) │         50 │ dec_os32_cbam_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_3_sp… │ (None, 80, 80,    │          0 │ dec_os32_cbam_3_… │
# │ (Multiply)          │ 128)              │            │ dec_os32_cbam_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_conv_afte… │ (None, 80, 80,    │     73,792 │ dec_os32_cbam_3_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 80, 80,    │          0 │ dec_os32_conv_af… │
# │ (SpatialDropout2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_upconv_4   │ (None, 160, 160,  │     18,464 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_crop_skip… │ (None, 160, 160,  │          0 │ dec_os32_upconv_… │
# │ (Lambda)            │ 64)               │            │ enc_os32_bn1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 160, 160,  │      1,040 │ dec_os32_crop_sk… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 160, 160,  │        528 │ dec_os32_upconv_… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 160, 160,  │          0 │ conv2d_9[0][0],   │
# │                     │ 16)               │            │ conv2d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 160, 160,  │          0 │ add_3[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 160, 160,  │         17 │ activation_3[0][… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 160, 160,  │          0 │ dec_os32_crop_sk… │
# │ (Multiply)          │ 64)               │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_concat_sk… │ (None, 160, 160,  │          0 │ dec_os32_upconv_… │
# │ (Concatenate)       │ 96)               │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 96)        │          0 │ dec_os32_concat_… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 96)        │          0 │ dec_os32_concat_… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 1, 1, 96)  │          0 │ dec_os32_cbam_4_… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 1, 1, 96)  │          0 │ dec_os32_cbam_4_… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 1, 1, 12)  │      1,152 │ dec_os32_cbam_4_… │
# │ (Dense)             │                   │            │ dec_os32_cbam_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 1, 1, 96)  │      1,152 │ dec_os32_cbam_4_… │
# │ (Dense)             │                   │            │ dec_os32_cbam_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 1, 1, 96)  │          0 │ dec_os32_cbam_4_… │
# │ (Add)               │                   │            │ dec_os32_cbam_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 1, 1, 96)  │          0 │ dec_os32_cbam_4_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_ch… │ (None, 160, 160,  │          0 │ dec_os32_concat_… │
# │ (Multiply)          │ 96)               │            │ dec_os32_cbam_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_sp… │ (None, 160, 160,  │          0 │ dec_os32_cbam_4_… │
# │ (GlobalChannelMean… │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_sp… │ (None, 160, 160,  │          0 │ dec_os32_cbam_4_… │
# │ (GlobalChannelMaxP… │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_sp… │ (None, 160, 160,  │          0 │ dec_os32_cbam_4_… │
# │ (Concatenate)       │ 2)                │            │ dec_os32_cbam_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_sp… │ (None, 160, 160,  │         50 │ dec_os32_cbam_4_… │
# │ (Conv2D)            │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_cbam_4_sp… │ (None, 160, 160,  │          0 │ dec_os32_cbam_4_… │
# │ (Multiply)          │ 96)               │            │ dec_os32_cbam_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_conv_afte… │ (None, 160, 160,  │     27,680 │ dec_os32_cbam_4_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_3 │ (None, 160, 160,  │          0 │ dec_os32_conv_af… │
# │ (SpatialDropout2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_os32_final_ups… │ (None, 320, 320,  │     18,496 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_1    │ (None, 320, 320,  │     36,928 │ dec_os32_final_u… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_bn_1 │ (None, 320, 320,  │        256 │ decoder_refine_1… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_refine_2    │ (None, 320, 320,  │     36,928 │ decoder_refine_b… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_layer        │ (None, 320, 320,  │        455 │ decoder_refine_2… │
# │ (Conv2D)            │ 7)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 19,038,905 (72.63 MB)
#  Trainable params: 19,005,721 (72.50 MB)
#  Non-trainable params: 33,184 (129.62 KB)

# %% [markdown]
# ## Train Model

# %%
val_images = []
val_masks = []
for img, mask in test_dataset:
    val_images.append(img.numpy())
    val_masks.append(mask.numpy())
val_images = np.concatenate(val_images, axis=0)
val_masks = np.concatenate(val_masks, axis=0)
# Out:
# 2025-06-02 20:36:58.635358: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_iou_adapted', 
    factor=0.5, 
    patience=50,
    verbose=0,
    mode='max', 
    min_lr=0.0000001
)

# %%
mean_iou_metric = MeanIoUAdapted(num_classes_metric=NUM_MODEL_CLASSES)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss=combined_loss_multiclass_sparse_from_probs(alpha=0.5, beta=0.5), 
    metrics=['accuracy', mean_iou_metric] 
)

# %%
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=500,
    callbacks=[
        reduce_lr_on_plateau,
    ],    
)
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748871442.814187 2269199 service.cc:152] XLA service 0x7f2b100025b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748871442.814320 2269199 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2025-06-02 20:37:24.099076: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-06-02 20:37:25.893098: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-06-02 20:37:25.894902: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_non_negative/assert_less_equal/Assert/AssertGuard/Assert
# 2025-06-02 20:37:25.896255: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_non_negative_1/assert_less_equal/Assert/AssertGuard/Assert
# 2025-06-02 20:37:25.898291: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_less/Assert/AssertGuard/Assert
# 2025-06-02 20:37:25.899861: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_less_1/Assert/AssertGuard/Assert
# I0000 00:00:1748871448.029600 2269199 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 2025-06-02 20:38:28.209211: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_12', 136 bytes spill stores, 108 bytes spill loads
#  1/50 ━━━━━━━━━━━━━━━━━━━━ 1:13:39 90s/step - accuracy: 0.1771 - loss: 1.9425 - mean_iou_adapted: 0.0613
# I0000 00:00:1748871508.740113 2269199 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3758 - loss: 1.6765 - mean_iou_adapted: 0.1184
# 2025-06-02 20:38:36.218328: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-06-02 20:38:36.219154: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_non_negative/assert_less_equal/Assert/AssertGuard/Assert
# 2025-06-02 20:38:36.219903: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_non_negative_1/assert_less_equal/Assert/AssertGuard/Assert
# 2025-06-02 20:38:36.221062: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_less/Assert/AssertGuard/Assert
# 2025-06-02 20:38:36.221967: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_less_1/Assert/AssertGuard/Assert
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3768 - loss: 1.6729 - mean_iou_adapted: 0.1188
# 2025-06-02 20:39:23.553061: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-06-02 20:39:23.554740: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_non_negative/assert_less_equal/Assert/AssertGuard/Assert
# 2025-06-02 20:39:23.555961: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_non_negative_1/assert_less_equal/Assert/AssertGuard/Assert
# 2025-06-02 20:39:23.557739: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_less/Assert/AssertGuard/Assert
# 2025-06-02 20:39:23.559155: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_less_1/Assert/AssertGuard/Assert
# 2025-06-02 20:39:30.295816: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-06-02 20:39:30.296668: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_non_negative/assert_less_equal/Assert/AssertGuard/Assert
# 2025-06-02 20:39:30.297429: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_non_negative_1/assert_less_equal/Assert/AssertGuard/Assert
# 2025-06-02 20:39:30.298537: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_less/Assert/AssertGuard/Assert
# 2025-06-02 20:39:30.299469: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator confusion_matrix/assert_less_1/Assert/AssertGuard/Assert
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.3777 - loss: 1.6695 - mean_iou_adapted: 0.1191 - val_accuracy: 0.5289 - val_loss: 1.5379 - val_mean_iou_adapted: 0.0756 - learning_rate: 5.0000e-04
# Epoch 2/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.4929 - loss: 1.1811 - mean_iou_adapted: 0.1700 - val_accuracy: 0.5289 - val_loss: 1.4426 - val_mean_iou_adapted: 0.0756 - learning_rate: 5.0000e-04
# Epoch 3/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.5050 - loss: 1.1057 - mean_iou_adapted: 0.2046 - val_accuracy: 0.5289 - val_loss: 1.4011 - val_mean_iou_adapted: 0.0756 - learning_rate: 5.0000e-04
# Epoch 4/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.4876 - loss: 1.0878 - mean_iou_adapted: 0.1900 - val_accuracy: 0.5213 - val_loss: 1.3861 - val_mean_iou_adapted: 0.1124 - learning_rate: 5.0000e-04
# Epoch 5/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.5088 - loss: 1.0591 - mean_iou_adapted: 0.2106 - val_accuracy: 0.5403 - val_loss: 1.3309 - val_mean_iou_adapted: 0.1484 - learning_rate: 5.0000e-04
# Epoch 6/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.5134 - loss: 1.0573 - mean_iou_adapted: 0.2258 - val_accuracy: 0.5806 - val_loss: 1.2503 - val_mean_iou_adapted: 0.1737 - learning_rate: 5.0000e-04
# Epoch 7/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.5289 - loss: 1.0363 - mean_iou_adapted: 0.2239 - val_accuracy: 0.5340 - val_loss: 1.2535 - val_mean_iou_adapted: 0.2279 - learning_rate: 5.0000e-04
# Epoch 8/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.5560 - loss: 1.0041 - mean_iou_adapted: 0.2878 - val_accuracy: 0.5530 - val_loss: 1.0714 - val_mean_iou_adapted: 0.1428 - learning_rate: 5.0000e-04
# Epoch 9/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.5656 - loss: 0.9942 - mean_iou_adapted: 0.3003 - val_accuracy: 0.6398 - val_loss: 1.0355 - val_mean_iou_adapted: 0.3297 - learning_rate: 5.0000e-04
# Epoch 10/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.5730 - loss: 0.9828 - mean_iou_adapted: 0.3105 - val_accuracy: 0.6142 - val_loss: 0.9661 - val_mean_iou_adapted: 0.2894 - learning_rate: 5.0000e-04
# Epoch 11/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.5869 - loss: 0.9768 - mean_iou_adapted: 0.3284 - val_accuracy: 0.6269 - val_loss: 0.9287 - val_mean_iou_adapted: 0.2801 - learning_rate: 5.0000e-04
# Epoch 12/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.5852 - loss: 0.9721 - mean_iou_adapted: 0.3212 - val_accuracy: 0.6429 - val_loss: 0.8834 - val_mean_iou_adapted: 0.2940 - learning_rate: 5.0000e-04
# Epoch 13/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6152 - loss: 0.9382 - mean_iou_adapted: 0.3406 - val_accuracy: 0.5735 - val_loss: 0.9879 - val_mean_iou_adapted: 0.3235 - learning_rate: 5.0000e-04
# Epoch 14/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.5812 - loss: 0.9672 - mean_iou_adapted: 0.3210 - val_accuracy: 0.5869 - val_loss: 0.9631 - val_mean_iou_adapted: 0.3276 - learning_rate: 5.0000e-04
# Epoch 15/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.6054 - loss: 0.9309 - mean_iou_adapted: 0.3478 - val_accuracy: 0.6712 - val_loss: 0.8921 - val_mean_iou_adapted: 0.3799 - learning_rate: 5.0000e-04
# Epoch 16/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.6186 - loss: 0.9391 - mean_iou_adapted: 0.3668 - val_accuracy: 0.6372 - val_loss: 0.9198 - val_mean_iou_adapted: 0.3130 - learning_rate: 5.0000e-04
# Epoch 17/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.5997 - loss: 0.9603 - mean_iou_adapted: 0.3473 - val_accuracy: 0.6700 - val_loss: 0.8472 - val_mean_iou_adapted: 0.3717 - learning_rate: 5.0000e-04
# Epoch 18/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.5987 - loss: 0.9592 - mean_iou_adapted: 0.3372 - val_accuracy: 0.6869 - val_loss: 0.8318 - val_mean_iou_adapted: 0.4211 - learning_rate: 5.0000e-04
# Epoch 19/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6333 - loss: 0.9096 - mean_iou_adapted: 0.3808 - val_accuracy: 0.6202 - val_loss: 0.9008 - val_mean_iou_adapted: 0.3259 - learning_rate: 5.0000e-04
# Epoch 20/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.6340 - loss: 0.9125 - mean_iou_adapted: 0.3545 - val_accuracy: 0.5796 - val_loss: 1.0781 - val_mean_iou_adapted: 0.2135 - learning_rate: 5.0000e-04
# Epoch 21/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.6094 - loss: 0.9433 - mean_iou_adapted: 0.3496 - val_accuracy: 0.6758 - val_loss: 0.8469 - val_mean_iou_adapted: 0.3751 - learning_rate: 5.0000e-04
# Epoch 22/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.6330 - loss: 0.9092 - mean_iou_adapted: 0.3754 - val_accuracy: 0.6247 - val_loss: 0.9628 - val_mean_iou_adapted: 0.2994 - learning_rate: 5.0000e-04
# Epoch 23/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.6084 - loss: 0.9477 - mean_iou_adapted: 0.3575 - val_accuracy: 0.7477 - val_loss: 0.7560 - val_mean_iou_adapted: 0.4577 - learning_rate: 5.0000e-04
# Epoch 24/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.6453 - loss: 0.8953 - mean_iou_adapted: 0.3900 - val_accuracy: 0.6493 - val_loss: 0.9153 - val_mean_iou_adapted: 0.3498 - learning_rate: 5.0000e-04
# Epoch 25/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6542 - loss: 0.8903 - mean_iou_adapted: 0.3979 - val_accuracy: 0.7186 - val_loss: 0.7973 - val_mean_iou_adapted: 0.4807 - learning_rate: 5.0000e-04
# Epoch 26/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6494 - loss: 0.8893 - mean_iou_adapted: 0.4154 - val_accuracy: 0.7256 - val_loss: 0.8018 - val_mean_iou_adapted: 0.4646 - learning_rate: 5.0000e-04
# Epoch 27/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.6760 - loss: 0.8556 - mean_iou_adapted: 0.4198 - val_accuracy: 0.6503 - val_loss: 0.8750 - val_mean_iou_adapted: 0.3789 - learning_rate: 5.0000e-04
# Epoch 28/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.6523 - loss: 0.8930 - mean_iou_adapted: 0.4139 - val_accuracy: 0.7478 - val_loss: 0.7556 - val_mean_iou_adapted: 0.4969 - learning_rate: 5.0000e-04
# Epoch 29/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.6811 - loss: 0.8606 - mean_iou_adapted: 0.4412 - val_accuracy: 0.7301 - val_loss: 0.7748 - val_mean_iou_adapted: 0.4706 - learning_rate: 5.0000e-04
# Epoch 30/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6426 - loss: 0.8911 - mean_iou_adapted: 0.4097 - val_accuracy: 0.7410 - val_loss: 0.7593 - val_mean_iou_adapted: 0.4665 - learning_rate: 5.0000e-04
# Epoch 31/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6512 - loss: 0.8760 - mean_iou_adapted: 0.3983 - val_accuracy: 0.6295 - val_loss: 0.9049 - val_mean_iou_adapted: 0.3842 - learning_rate: 5.0000e-04
# Epoch 32/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6395 - loss: 0.8914 - mean_iou_adapted: 0.4008 - val_accuracy: 0.6808 - val_loss: 0.8532 - val_mean_iou_adapted: 0.3755 - learning_rate: 5.0000e-04
# Epoch 33/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.6820 - loss: 0.8596 - mean_iou_adapted: 0.4349 - val_accuracy: 0.6331 - val_loss: 0.9423 - val_mean_iou_adapted: 0.3600 - learning_rate: 5.0000e-04
# Epoch 34/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6733 - loss: 0.8650 - mean_iou_adapted: 0.4322 - val_accuracy: 0.7247 - val_loss: 0.7881 - val_mean_iou_adapted: 0.4696 - learning_rate: 5.0000e-04
# Epoch 35/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.6892 - loss: 0.8600 - mean_iou_adapted: 0.4538 - val_accuracy: 0.7074 - val_loss: 0.8119 - val_mean_iou_adapted: 0.3741 - learning_rate: 5.0000e-04
# Epoch 36/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.6732 - loss: 0.8497 - mean_iou_adapted: 0.4347 - val_accuracy: 0.7026 - val_loss: 0.8192 - val_mean_iou_adapted: 0.4555 - learning_rate: 5.0000e-04
# Epoch 37/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.6934 - loss: 0.8266 - mean_iou_adapted: 0.4657 - val_accuracy: 0.7513 - val_loss: 0.7448 - val_mean_iou_adapted: 0.4936 - learning_rate: 5.0000e-04
# Epoch 38/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.6873 - loss: 0.8473 - mean_iou_adapted: 0.4459 - val_accuracy: 0.7474 - val_loss: 0.7760 - val_mean_iou_adapted: 0.4609 - learning_rate: 5.0000e-04
# Epoch 39/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7003 - loss: 0.8142 - mean_iou_adapted: 0.4538 - val_accuracy: 0.7415 - val_loss: 0.7482 - val_mean_iou_adapted: 0.4355 - learning_rate: 5.0000e-04
# Epoch 40/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7154 - loss: 0.8080 - mean_iou_adapted: 0.4634 - val_accuracy: 0.6647 - val_loss: 0.8793 - val_mean_iou_adapted: 0.3915 - learning_rate: 5.0000e-04
# Epoch 41/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.6932 - loss: 0.8387 - mean_iou_adapted: 0.4662 - val_accuracy: 0.7512 - val_loss: 0.7567 - val_mean_iou_adapted: 0.4896 - learning_rate: 5.0000e-04
# Epoch 42/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.7047 - loss: 0.8321 - mean_iou_adapted: 0.4654 - val_accuracy: 0.7504 - val_loss: 0.7548 - val_mean_iou_adapted: 0.4945 - learning_rate: 5.0000e-04
# Epoch 43/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7070 - loss: 0.8251 - mean_iou_adapted: 0.4648 - val_accuracy: 0.7019 - val_loss: 0.8199 - val_mean_iou_adapted: 0.4210 - learning_rate: 5.0000e-04
# Epoch 44/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7027 - loss: 0.8292 - mean_iou_adapted: 0.4425 - val_accuracy: 0.7261 - val_loss: 0.7615 - val_mean_iou_adapted: 0.4836 - learning_rate: 5.0000e-04
# Epoch 45/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.6948 - loss: 0.8195 - mean_iou_adapted: 0.4648 - val_accuracy: 0.7380 - val_loss: 0.7866 - val_mean_iou_adapted: 0.4358 - learning_rate: 5.0000e-04
# Epoch 46/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7112 - loss: 0.8016 - mean_iou_adapted: 0.4742 - val_accuracy: 0.7572 - val_loss: 0.7422 - val_mean_iou_adapted: 0.5243 - learning_rate: 5.0000e-04
# Epoch 47/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.6908 - loss: 0.8360 - mean_iou_adapted: 0.4504 - val_accuracy: 0.7839 - val_loss: 0.6999 - val_mean_iou_adapted: 0.5793 - learning_rate: 5.0000e-04
# Epoch 48/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.7293 - loss: 0.7773 - mean_iou_adapted: 0.5080 - val_accuracy: 0.7437 - val_loss: 0.7591 - val_mean_iou_adapted: 0.5102 - learning_rate: 5.0000e-04
# Epoch 49/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7004 - loss: 0.8168 - mean_iou_adapted: 0.4688 - val_accuracy: 0.6141 - val_loss: 0.9538 - val_mean_iou_adapted: 0.3788 - learning_rate: 5.0000e-04
# Epoch 50/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7033 - loss: 0.8159 - mean_iou_adapted: 0.4814 - val_accuracy: 0.7159 - val_loss: 0.7624 - val_mean_iou_adapted: 0.4743 - learning_rate: 5.0000e-04
# Epoch 51/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7124 - loss: 0.8194 - mean_iou_adapted: 0.4723 - val_accuracy: 0.6962 - val_loss: 0.7936 - val_mean_iou_adapted: 0.3859 - learning_rate: 5.0000e-04
# Epoch 52/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.7242 - loss: 0.7944 - mean_iou_adapted: 0.4819 - val_accuracy: 0.7631 - val_loss: 0.7219 - val_mean_iou_adapted: 0.4783 - learning_rate: 5.0000e-04
# Epoch 53/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7304 - loss: 0.7928 - mean_iou_adapted: 0.5166 - val_accuracy: 0.8065 - val_loss: 0.6642 - val_mean_iou_adapted: 0.5892 - learning_rate: 5.0000e-04
# Epoch 54/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7439 - loss: 0.7696 - mean_iou_adapted: 0.5262 - val_accuracy: 0.7598 - val_loss: 0.7371 - val_mean_iou_adapted: 0.5415 - learning_rate: 5.0000e-04
# Epoch 55/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.7347 - loss: 0.7756 - mean_iou_adapted: 0.5112 - val_accuracy: 0.7789 - val_loss: 0.7044 - val_mean_iou_adapted: 0.5289 - learning_rate: 5.0000e-04
# Epoch 56/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7291 - loss: 0.7831 - mean_iou_adapted: 0.4962 - val_accuracy: 0.7626 - val_loss: 0.7389 - val_mean_iou_adapted: 0.5588 - learning_rate: 5.0000e-04
# Epoch 57/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7394 - loss: 0.7718 - mean_iou_adapted: 0.5208 - val_accuracy: 0.8029 - val_loss: 0.6624 - val_mean_iou_adapted: 0.5878 - learning_rate: 5.0000e-04
# Epoch 58/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7529 - loss: 0.7531 - mean_iou_adapted: 0.5439 - val_accuracy: 0.7753 - val_loss: 0.7028 - val_mean_iou_adapted: 0.5044 - learning_rate: 5.0000e-04
# Epoch 59/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7132 - loss: 0.8044 - mean_iou_adapted: 0.4662 - val_accuracy: 0.7932 - val_loss: 0.6969 - val_mean_iou_adapted: 0.5825 - learning_rate: 5.0000e-04
# Epoch 60/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7607 - loss: 0.7302 - mean_iou_adapted: 0.5365 - val_accuracy: 0.7558 - val_loss: 0.7477 - val_mean_iou_adapted: 0.5584 - learning_rate: 5.0000e-04
# Epoch 61/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7250 - loss: 0.7882 - mean_iou_adapted: 0.5080 - val_accuracy: 0.7613 - val_loss: 0.7368 - val_mean_iou_adapted: 0.4878 - learning_rate: 5.0000e-04
# Epoch 62/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.7182 - loss: 0.7945 - mean_iou_adapted: 0.4954 - val_accuracy: 0.7905 - val_loss: 0.6821 - val_mean_iou_adapted: 0.5542 - learning_rate: 5.0000e-04
# Epoch 63/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7432 - loss: 0.7591 - mean_iou_adapted: 0.5163 - val_accuracy: 0.8140 - val_loss: 0.6540 - val_mean_iou_adapted: 0.6123 - learning_rate: 5.0000e-04
# Epoch 64/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.7287 - loss: 0.7819 - mean_iou_adapted: 0.4936 - val_accuracy: 0.7950 - val_loss: 0.6818 - val_mean_iou_adapted: 0.5826 - learning_rate: 5.0000e-04
# Epoch 65/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7333 - loss: 0.7790 - mean_iou_adapted: 0.5022 - val_accuracy: 0.7847 - val_loss: 0.6829 - val_mean_iou_adapted: 0.5821 - learning_rate: 5.0000e-04
# Epoch 66/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7332 - loss: 0.7675 - mean_iou_adapted: 0.4989 - val_accuracy: 0.7865 - val_loss: 0.6839 - val_mean_iou_adapted: 0.5852 - learning_rate: 5.0000e-04
# Epoch 67/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7552 - loss: 0.7410 - mean_iou_adapted: 0.5418 - val_accuracy: 0.7702 - val_loss: 0.7018 - val_mean_iou_adapted: 0.5305 - learning_rate: 5.0000e-04
# Epoch 68/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7246 - loss: 0.7881 - mean_iou_adapted: 0.4894 - val_accuracy: 0.7618 - val_loss: 0.7297 - val_mean_iou_adapted: 0.5171 - learning_rate: 5.0000e-04
# Epoch 69/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.7486 - loss: 0.7544 - mean_iou_adapted: 0.5210 - val_accuracy: 0.8008 - val_loss: 0.6783 - val_mean_iou_adapted: 0.5941 - learning_rate: 5.0000e-04
# Epoch 70/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7529 - loss: 0.7434 - mean_iou_adapted: 0.5296 - val_accuracy: 0.7645 - val_loss: 0.7041 - val_mean_iou_adapted: 0.5652 - learning_rate: 5.0000e-04
# Epoch 71/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.7345 - loss: 0.7816 - mean_iou_adapted: 0.5094 - val_accuracy: 0.8065 - val_loss: 0.6636 - val_mean_iou_adapted: 0.5856 - learning_rate: 5.0000e-04
# Epoch 72/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7610 - loss: 0.7375 - mean_iou_adapted: 0.5564 - val_accuracy: 0.8157 - val_loss: 0.6482 - val_mean_iou_adapted: 0.6300 - learning_rate: 5.0000e-04
# Epoch 73/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7301 - loss: 0.7852 - mean_iou_adapted: 0.5055 - val_accuracy: 0.8188 - val_loss: 0.6605 - val_mean_iou_adapted: 0.6339 - learning_rate: 5.0000e-04
# Epoch 74/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7778 - loss: 0.7189 - mean_iou_adapted: 0.5613 - val_accuracy: 0.8207 - val_loss: 0.6583 - val_mean_iou_adapted: 0.6146 - learning_rate: 5.0000e-04
# Epoch 75/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7683 - loss: 0.7453 - mean_iou_adapted: 0.5471 - val_accuracy: 0.8187 - val_loss: 0.6398 - val_mean_iou_adapted: 0.6361 - learning_rate: 5.0000e-04
# Epoch 76/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.7707 - loss: 0.7139 - mean_iou_adapted: 0.5526 - val_accuracy: 0.8143 - val_loss: 0.6519 - val_mean_iou_adapted: 0.6277 - learning_rate: 5.0000e-04
# Epoch 77/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.7689 - loss: 0.7205 - mean_iou_adapted: 0.5652 - val_accuracy: 0.7828 - val_loss: 0.6925 - val_mean_iou_adapted: 0.5431 - learning_rate: 5.0000e-04
# Epoch 78/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7371 - loss: 0.7675 - mean_iou_adapted: 0.5191 - val_accuracy: 0.7803 - val_loss: 0.6959 - val_mean_iou_adapted: 0.5845 - learning_rate: 5.0000e-04
# Epoch 79/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7651 - loss: 0.7395 - mean_iou_adapted: 0.5451 - val_accuracy: 0.7595 - val_loss: 0.7260 - val_mean_iou_adapted: 0.5574 - learning_rate: 5.0000e-04
# Epoch 80/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.7637 - loss: 0.7537 - mean_iou_adapted: 0.5481 - val_accuracy: 0.8323 - val_loss: 0.6344 - val_mean_iou_adapted: 0.6605 - learning_rate: 5.0000e-04
# Epoch 81/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.7737 - loss: 0.7246 - mean_iou_adapted: 0.5423 - val_accuracy: 0.7946 - val_loss: 0.6977 - val_mean_iou_adapted: 0.5923 - learning_rate: 5.0000e-04
# Epoch 82/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7726 - loss: 0.7186 - mean_iou_adapted: 0.5528 - val_accuracy: 0.7810 - val_loss: 0.6972 - val_mean_iou_adapted: 0.5434 - learning_rate: 5.0000e-04
# Epoch 83/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7344 - loss: 0.7837 - mean_iou_adapted: 0.5057 - val_accuracy: 0.7994 - val_loss: 0.6611 - val_mean_iou_adapted: 0.6056 - learning_rate: 5.0000e-04
# Epoch 84/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.7541 - loss: 0.7581 - mean_iou_adapted: 0.5404 - val_accuracy: 0.8297 - val_loss: 0.6358 - val_mean_iou_adapted: 0.6469 - learning_rate: 5.0000e-04
# Epoch 85/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7520 - loss: 0.7626 - mean_iou_adapted: 0.5353 - val_accuracy: 0.7868 - val_loss: 0.6836 - val_mean_iou_adapted: 0.5880 - learning_rate: 5.0000e-04
# Epoch 86/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.7998 - loss: 0.6880 - mean_iou_adapted: 0.6151 - val_accuracy: 0.7770 - val_loss: 0.6997 - val_mean_iou_adapted: 0.5765 - learning_rate: 5.0000e-04
# Epoch 87/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7900 - loss: 0.6983 - mean_iou_adapted: 0.5859 - val_accuracy: 0.8262 - val_loss: 0.6349 - val_mean_iou_adapted: 0.6286 - learning_rate: 5.0000e-04
# Epoch 88/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7868 - loss: 0.7053 - mean_iou_adapted: 0.5802 - val_accuracy: 0.8162 - val_loss: 0.6323 - val_mean_iou_adapted: 0.6291 - learning_rate: 5.0000e-04
# Epoch 89/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7635 - loss: 0.7206 - mean_iou_adapted: 0.5632 - val_accuracy: 0.8200 - val_loss: 0.6407 - val_mean_iou_adapted: 0.6241 - learning_rate: 5.0000e-04
# Epoch 90/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7688 - loss: 0.7239 - mean_iou_adapted: 0.5600 - val_accuracy: 0.7916 - val_loss: 0.6526 - val_mean_iou_adapted: 0.5892 - learning_rate: 5.0000e-04
# Epoch 91/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.7811 - loss: 0.7019 - mean_iou_adapted: 0.5878 - val_accuracy: 0.8212 - val_loss: 0.6243 - val_mean_iou_adapted: 0.6366 - learning_rate: 5.0000e-04
# Epoch 92/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7930 - loss: 0.6889 - mean_iou_adapted: 0.6104 - val_accuracy: 0.7692 - val_loss: 0.7426 - val_mean_iou_adapted: 0.5012 - learning_rate: 5.0000e-04
# Epoch 93/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7488 - loss: 0.7592 - mean_iou_adapted: 0.5278 - val_accuracy: 0.8137 - val_loss: 0.6562 - val_mean_iou_adapted: 0.6293 - learning_rate: 5.0000e-04
# Epoch 94/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7921 - loss: 0.6832 - mean_iou_adapted: 0.6007 - val_accuracy: 0.8019 - val_loss: 0.6407 - val_mean_iou_adapted: 0.6136 - learning_rate: 5.0000e-04
# Epoch 95/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7879 - loss: 0.6964 - mean_iou_adapted: 0.5918 - val_accuracy: 0.8209 - val_loss: 0.6445 - val_mean_iou_adapted: 0.6275 - learning_rate: 5.0000e-04
# Epoch 96/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8040 - loss: 0.6614 - mean_iou_adapted: 0.6242 - val_accuracy: 0.8292 - val_loss: 0.6247 - val_mean_iou_adapted: 0.6508 - learning_rate: 5.0000e-04
# Epoch 97/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.7586 - loss: 0.7337 - mean_iou_adapted: 0.5562 - val_accuracy: 0.8153 - val_loss: 0.6389 - val_mean_iou_adapted: 0.6232 - learning_rate: 5.0000e-04
# Epoch 98/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7666 - loss: 0.7360 - mean_iou_adapted: 0.5631 - val_accuracy: 0.8105 - val_loss: 0.6577 - val_mean_iou_adapted: 0.5987 - learning_rate: 5.0000e-04
# Epoch 99/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7826 - loss: 0.7199 - mean_iou_adapted: 0.5784 - val_accuracy: 0.8529 - val_loss: 0.5986 - val_mean_iou_adapted: 0.6932 - learning_rate: 5.0000e-04
# Epoch 100/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.8039 - loss: 0.6835 - mean_iou_adapted: 0.6171 - val_accuracy: 0.8322 - val_loss: 0.6326 - val_mean_iou_adapted: 0.6625 - learning_rate: 5.0000e-04
# Epoch 101/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.7756 - loss: 0.7092 - mean_iou_adapted: 0.5671 - val_accuracy: 0.8240 - val_loss: 0.6347 - val_mean_iou_adapted: 0.6510 - learning_rate: 5.0000e-04
# Epoch 102/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7925 - loss: 0.7023 - mean_iou_adapted: 0.5932 - val_accuracy: 0.7750 - val_loss: 0.7090 - val_mean_iou_adapted: 0.5206 - learning_rate: 5.0000e-04
# Epoch 103/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7865 - loss: 0.6934 - mean_iou_adapted: 0.6024 - val_accuracy: 0.8284 - val_loss: 0.6310 - val_mean_iou_adapted: 0.6513 - learning_rate: 5.0000e-04
# Epoch 104/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7904 - loss: 0.6924 - mean_iou_adapted: 0.5910 - val_accuracy: 0.8301 - val_loss: 0.6396 - val_mean_iou_adapted: 0.6389 - learning_rate: 5.0000e-04
# Epoch 105/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7886 - loss: 0.6941 - mean_iou_adapted: 0.5865 - val_accuracy: 0.8449 - val_loss: 0.6077 - val_mean_iou_adapted: 0.6735 - learning_rate: 5.0000e-04
# Epoch 106/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.8070 - loss: 0.6665 - mean_iou_adapted: 0.6337 - val_accuracy: 0.8015 - val_loss: 0.6634 - val_mean_iou_adapted: 0.6072 - learning_rate: 5.0000e-04
# Epoch 107/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7652 - loss: 0.7151 - mean_iou_adapted: 0.5607 - val_accuracy: 0.8330 - val_loss: 0.6319 - val_mean_iou_adapted: 0.6629 - learning_rate: 5.0000e-04
# Epoch 108/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7842 - loss: 0.7135 - mean_iou_adapted: 0.5923 - val_accuracy: 0.8226 - val_loss: 0.6304 - val_mean_iou_adapted: 0.6184 - learning_rate: 5.0000e-04
# Epoch 109/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7849 - loss: 0.7100 - mean_iou_adapted: 0.5955 - val_accuracy: 0.8112 - val_loss: 0.6441 - val_mean_iou_adapted: 0.6231 - learning_rate: 5.0000e-04
# Epoch 110/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7941 - loss: 0.6774 - mean_iou_adapted: 0.5935 - val_accuracy: 0.8208 - val_loss: 0.6375 - val_mean_iou_adapted: 0.6388 - learning_rate: 5.0000e-04
# Epoch 111/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.8215 - loss: 0.6434 - mean_iou_adapted: 0.6379 - val_accuracy: 0.8096 - val_loss: 0.6446 - val_mean_iou_adapted: 0.5730 - learning_rate: 5.0000e-04
# Epoch 112/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.7996 - loss: 0.6762 - mean_iou_adapted: 0.5937 - val_accuracy: 0.8117 - val_loss: 0.6536 - val_mean_iou_adapted: 0.6277 - learning_rate: 5.0000e-04
# Epoch 113/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7882 - loss: 0.7013 - mean_iou_adapted: 0.6029 - val_accuracy: 0.8329 - val_loss: 0.6482 - val_mean_iou_adapted: 0.6415 - learning_rate: 5.0000e-04
# Epoch 114/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8121 - loss: 0.6828 - mean_iou_adapted: 0.6283 - val_accuracy: 0.7960 - val_loss: 0.6550 - val_mean_iou_adapted: 0.5736 - learning_rate: 5.0000e-04
# Epoch 115/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.7973 - loss: 0.6732 - mean_iou_adapted: 0.6023 - val_accuracy: 0.8163 - val_loss: 0.6639 - val_mean_iou_adapted: 0.6316 - learning_rate: 5.0000e-04
# Epoch 116/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.7942 - loss: 0.6876 - mean_iou_adapted: 0.5936 - val_accuracy: 0.7968 - val_loss: 0.6616 - val_mean_iou_adapted: 0.6141 - learning_rate: 5.0000e-04
# Epoch 117/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7790 - loss: 0.7259 - mean_iou_adapted: 0.5929 - val_accuracy: 0.8364 - val_loss: 0.6329 - val_mean_iou_adapted: 0.6397 - learning_rate: 5.0000e-04
# Epoch 118/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7957 - loss: 0.6824 - mean_iou_adapted: 0.6114 - val_accuracy: 0.8284 - val_loss: 0.6298 - val_mean_iou_adapted: 0.6536 - learning_rate: 5.0000e-04
# Epoch 119/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7867 - loss: 0.6949 - mean_iou_adapted: 0.5803 - val_accuracy: 0.7922 - val_loss: 0.6989 - val_mean_iou_adapted: 0.5995 - learning_rate: 5.0000e-04
# Epoch 120/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7995 - loss: 0.6771 - mean_iou_adapted: 0.6079 - val_accuracy: 0.8277 - val_loss: 0.6174 - val_mean_iou_adapted: 0.6381 - learning_rate: 5.0000e-04
# Epoch 121/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8050 - loss: 0.6752 - mean_iou_adapted: 0.6012 - val_accuracy: 0.8188 - val_loss: 0.6337 - val_mean_iou_adapted: 0.6502 - learning_rate: 5.0000e-04
# Epoch 122/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8143 - loss: 0.6666 - mean_iou_adapted: 0.6268 - val_accuracy: 0.7980 - val_loss: 0.6951 - val_mean_iou_adapted: 0.5584 - learning_rate: 5.0000e-04
# Epoch 123/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7960 - loss: 0.6861 - mean_iou_adapted: 0.6131 - val_accuracy: 0.8275 - val_loss: 0.6232 - val_mean_iou_adapted: 0.6437 - learning_rate: 5.0000e-04
# Epoch 124/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.8057 - loss: 0.6855 - mean_iou_adapted: 0.6304 - val_accuracy: 0.8299 - val_loss: 0.6297 - val_mean_iou_adapted: 0.6512 - learning_rate: 5.0000e-04
# Epoch 125/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8198 - loss: 0.6492 - mean_iou_adapted: 0.6357 - val_accuracy: 0.7886 - val_loss: 0.6896 - val_mean_iou_adapted: 0.5988 - learning_rate: 5.0000e-04
# Epoch 126/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8088 - loss: 0.6716 - mean_iou_adapted: 0.6096 - val_accuracy: 0.8389 - val_loss: 0.6274 - val_mean_iou_adapted: 0.6560 - learning_rate: 5.0000e-04
# Epoch 127/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8079 - loss: 0.6691 - mean_iou_adapted: 0.6288 - val_accuracy: 0.8380 - val_loss: 0.6229 - val_mean_iou_adapted: 0.6670 - learning_rate: 5.0000e-04
# Epoch 128/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8001 - loss: 0.6891 - mean_iou_adapted: 0.6118 - val_accuracy: 0.8345 - val_loss: 0.6251 - val_mean_iou_adapted: 0.6622 - learning_rate: 5.0000e-04
# Epoch 129/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8116 - loss: 0.6520 - mean_iou_adapted: 0.6317 - val_accuracy: 0.7757 - val_loss: 0.6895 - val_mean_iou_adapted: 0.5972 - learning_rate: 5.0000e-04
# Epoch 130/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7956 - loss: 0.6924 - mean_iou_adapted: 0.6119 - val_accuracy: 0.7981 - val_loss: 0.6636 - val_mean_iou_adapted: 0.6181 - learning_rate: 5.0000e-04
# Epoch 131/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8202 - loss: 0.6550 - mean_iou_adapted: 0.6383 - val_accuracy: 0.8426 - val_loss: 0.6163 - val_mean_iou_adapted: 0.6569 - learning_rate: 5.0000e-04
# Epoch 132/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8389 - loss: 0.6428 - mean_iou_adapted: 0.6671 - val_accuracy: 0.8167 - val_loss: 0.6410 - val_mean_iou_adapted: 0.6300 - learning_rate: 5.0000e-04
# Epoch 133/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8131 - loss: 0.6657 - mean_iou_adapted: 0.6348 - val_accuracy: 0.7997 - val_loss: 0.6871 - val_mean_iou_adapted: 0.6251 - learning_rate: 5.0000e-04
# Epoch 134/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8051 - loss: 0.6767 - mean_iou_adapted: 0.6148 - val_accuracy: 0.8334 - val_loss: 0.6223 - val_mean_iou_adapted: 0.6570 - learning_rate: 5.0000e-04
# Epoch 135/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.7990 - loss: 0.6907 - mean_iou_adapted: 0.6094 - val_accuracy: 0.8379 - val_loss: 0.6142 - val_mean_iou_adapted: 0.6709 - learning_rate: 5.0000e-04
# Epoch 136/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8339 - loss: 0.6270 - mean_iou_adapted: 0.6737 - val_accuracy: 0.8558 - val_loss: 0.6138 - val_mean_iou_adapted: 0.6967 - learning_rate: 5.0000e-04
# Epoch 137/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.7711 - loss: 0.7262 - mean_iou_adapted: 0.5575 - val_accuracy: 0.7625 - val_loss: 0.8833 - val_mean_iou_adapted: 0.5090 - learning_rate: 5.0000e-04
# Epoch 138/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.7723 - loss: 0.7140 - mean_iou_adapted: 0.5779 - val_accuracy: 0.8247 - val_loss: 0.6479 - val_mean_iou_adapted: 0.6161 - learning_rate: 5.0000e-04
# Epoch 139/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8161 - loss: 0.6642 - mean_iou_adapted: 0.6349 - val_accuracy: 0.8418 - val_loss: 0.6129 - val_mean_iou_adapted: 0.6575 - learning_rate: 5.0000e-04
# Epoch 140/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8029 - loss: 0.6831 - mean_iou_adapted: 0.6165 - val_accuracy: 0.8560 - val_loss: 0.5910 - val_mean_iou_adapted: 0.6892 - learning_rate: 5.0000e-04
# Epoch 141/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.8001 - loss: 0.6942 - mean_iou_adapted: 0.6112 - val_accuracy: 0.8379 - val_loss: 0.6169 - val_mean_iou_adapted: 0.6694 - learning_rate: 5.0000e-04
# Epoch 142/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8172 - loss: 0.6524 - mean_iou_adapted: 0.6303 - val_accuracy: 0.7997 - val_loss: 0.6459 - val_mean_iou_adapted: 0.5695 - learning_rate: 5.0000e-04
# Epoch 143/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8074 - loss: 0.6662 - mean_iou_adapted: 0.6256 - val_accuracy: 0.7898 - val_loss: 0.6760 - val_mean_iou_adapted: 0.5854 - learning_rate: 5.0000e-04
# Epoch 144/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8217 - loss: 0.6410 - mean_iou_adapted: 0.6445 - val_accuracy: 0.8388 - val_loss: 0.6335 - val_mean_iou_adapted: 0.6535 - learning_rate: 5.0000e-04
# Epoch 145/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8251 - loss: 0.6613 - mean_iou_adapted: 0.6583 - val_accuracy: 0.8096 - val_loss: 0.6586 - val_mean_iou_adapted: 0.6282 - learning_rate: 5.0000e-04
# Epoch 146/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.8219 - loss: 0.6443 - mean_iou_adapted: 0.6529 - val_accuracy: 0.8437 - val_loss: 0.6083 - val_mean_iou_adapted: 0.6753 - learning_rate: 5.0000e-04
# Epoch 147/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8015 - loss: 0.6844 - mean_iou_adapted: 0.6053 - val_accuracy: 0.8356 - val_loss: 0.6248 - val_mean_iou_adapted: 0.6290 - learning_rate: 5.0000e-04
# Epoch 148/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8292 - loss: 0.6409 - mean_iou_adapted: 0.6658 - val_accuracy: 0.8481 - val_loss: 0.6152 - val_mean_iou_adapted: 0.6847 - learning_rate: 5.0000e-04
# Epoch 149/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8169 - loss: 0.6662 - mean_iou_adapted: 0.6429 - val_accuracy: 0.7771 - val_loss: 0.6984 - val_mean_iou_adapted: 0.5862 - learning_rate: 5.0000e-04
# Epoch 150/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8244 - loss: 0.6378 - mean_iou_adapted: 0.6400 - val_accuracy: 0.8465 - val_loss: 0.6065 - val_mean_iou_adapted: 0.6803 - learning_rate: 5.0000e-04
# Epoch 151/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8250 - loss: 0.6568 - mean_iou_adapted: 0.6604 - val_accuracy: 0.8543 - val_loss: 0.5942 - val_mean_iou_adapted: 0.6916 - learning_rate: 5.0000e-04
# Epoch 152/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8086 - loss: 0.6746 - mean_iou_adapted: 0.6301 - val_accuracy: 0.8325 - val_loss: 0.6478 - val_mean_iou_adapted: 0.6680 - learning_rate: 5.0000e-04
# Epoch 153/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8368 - loss: 0.6357 - mean_iou_adapted: 0.6664 - val_accuracy: 0.8513 - val_loss: 0.6082 - val_mean_iou_adapted: 0.6805 - learning_rate: 5.0000e-04
# Epoch 154/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8444 - loss: 0.6174 - mean_iou_adapted: 0.6826 - val_accuracy: 0.8693 - val_loss: 0.5795 - val_mean_iou_adapted: 0.7144 - learning_rate: 5.0000e-04
# Epoch 155/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8578 - loss: 0.6066 - mean_iou_adapted: 0.7154 - val_accuracy: 0.8647 - val_loss: 0.5813 - val_mean_iou_adapted: 0.7180 - learning_rate: 5.0000e-04
# Epoch 156/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8250 - loss: 0.6416 - mean_iou_adapted: 0.6506 - val_accuracy: 0.8240 - val_loss: 0.6402 - val_mean_iou_adapted: 0.6408 - learning_rate: 5.0000e-04
# Epoch 157/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.8354 - loss: 0.6270 - mean_iou_adapted: 0.6702 - val_accuracy: 0.8349 - val_loss: 0.6394 - val_mean_iou_adapted: 0.6497 - learning_rate: 5.0000e-04
# Epoch 158/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8172 - loss: 0.6609 - mean_iou_adapted: 0.6396 - val_accuracy: 0.7857 - val_loss: 0.6963 - val_mean_iou_adapted: 0.5968 - learning_rate: 5.0000e-04
# Epoch 159/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8350 - loss: 0.6304 - mean_iou_adapted: 0.6700 - val_accuracy: 0.7970 - val_loss: 0.7014 - val_mean_iou_adapted: 0.5589 - learning_rate: 5.0000e-04
# Epoch 160/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8470 - loss: 0.6175 - mean_iou_adapted: 0.6851 - val_accuracy: 0.8223 - val_loss: 0.6418 - val_mean_iou_adapted: 0.6464 - learning_rate: 5.0000e-04
# Epoch 161/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8065 - loss: 0.6700 - mean_iou_adapted: 0.6308 - val_accuracy: 0.8466 - val_loss: 0.6225 - val_mean_iou_adapted: 0.6771 - learning_rate: 5.0000e-04
# Epoch 162/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8229 - loss: 0.6520 - mean_iou_adapted: 0.6453 - val_accuracy: 0.8534 - val_loss: 0.6133 - val_mean_iou_adapted: 0.6977 - learning_rate: 5.0000e-04
# Epoch 163/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8218 - loss: 0.6422 - mean_iou_adapted: 0.6457 - val_accuracy: 0.8398 - val_loss: 0.6277 - val_mean_iou_adapted: 0.6680 - learning_rate: 5.0000e-04
# Epoch 164/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8417 - loss: 0.6302 - mean_iou_adapted: 0.6909 - val_accuracy: 0.8282 - val_loss: 0.6330 - val_mean_iou_adapted: 0.6543 - learning_rate: 5.0000e-04
# Epoch 165/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8313 - loss: 0.6416 - mean_iou_adapted: 0.6657 - val_accuracy: 0.8688 - val_loss: 0.5888 - val_mean_iou_adapted: 0.7127 - learning_rate: 5.0000e-04
# Epoch 166/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8362 - loss: 0.6372 - mean_iou_adapted: 0.6675 - val_accuracy: 0.8511 - val_loss: 0.5970 - val_mean_iou_adapted: 0.6833 - learning_rate: 5.0000e-04
# Epoch 167/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8426 - loss: 0.6240 - mean_iou_adapted: 0.6830 - val_accuracy: 0.8315 - val_loss: 0.6337 - val_mean_iou_adapted: 0.6150 - learning_rate: 5.0000e-04
# Epoch 168/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8410 - loss: 0.6241 - mean_iou_adapted: 0.6809 - val_accuracy: 0.8205 - val_loss: 0.6625 - val_mean_iou_adapted: 0.6202 - learning_rate: 5.0000e-04
# Epoch 169/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8346 - loss: 0.6438 - mean_iou_adapted: 0.6630 - val_accuracy: 0.8447 - val_loss: 0.6103 - val_mean_iou_adapted: 0.6773 - learning_rate: 5.0000e-04
# Epoch 170/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8127 - loss: 0.6679 - mean_iou_adapted: 0.6371 - val_accuracy: 0.8443 - val_loss: 0.6113 - val_mean_iou_adapted: 0.6783 - learning_rate: 5.0000e-04
# Epoch 171/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.8402 - loss: 0.6341 - mean_iou_adapted: 0.6721 - val_accuracy: 0.8369 - val_loss: 0.6368 - val_mean_iou_adapted: 0.6784 - learning_rate: 5.0000e-04
# Epoch 172/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.8240 - loss: 0.6621 - mean_iou_adapted: 0.6574 - val_accuracy: 0.8114 - val_loss: 0.6584 - val_mean_iou_adapted: 0.6351 - learning_rate: 5.0000e-04
# Epoch 173/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.7935 - loss: 0.7129 - mean_iou_adapted: 0.6040 - val_accuracy: 0.8289 - val_loss: 0.6501 - val_mean_iou_adapted: 0.6606 - learning_rate: 5.0000e-04
# Epoch 174/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8584 - loss: 0.5929 - mean_iou_adapted: 0.7104 - val_accuracy: 0.8453 - val_loss: 0.6152 - val_mean_iou_adapted: 0.6811 - learning_rate: 5.0000e-04
# Epoch 175/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8372 - loss: 0.6304 - mean_iou_adapted: 0.6793 - val_accuracy: 0.8623 - val_loss: 0.5929 - val_mean_iou_adapted: 0.6945 - learning_rate: 5.0000e-04
# Epoch 176/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8050 - loss: 0.6713 - mean_iou_adapted: 0.6114 - val_accuracy: 0.8606 - val_loss: 0.5960 - val_mean_iou_adapted: 0.7038 - learning_rate: 5.0000e-04
# Epoch 177/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8367 - loss: 0.6383 - mean_iou_adapted: 0.6713 - val_accuracy: 0.8316 - val_loss: 0.6344 - val_mean_iou_adapted: 0.6650 - learning_rate: 5.0000e-04
# Epoch 178/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8454 - loss: 0.6202 - mean_iou_adapted: 0.6909 - val_accuracy: 0.8677 - val_loss: 0.5877 - val_mean_iou_adapted: 0.7178 - learning_rate: 5.0000e-04
# Epoch 179/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.8282 - loss: 0.6608 - mean_iou_adapted: 0.6493 - val_accuracy: 0.8534 - val_loss: 0.6014 - val_mean_iou_adapted: 0.6696 - learning_rate: 5.0000e-04
# Epoch 180/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8118 - loss: 0.6663 - mean_iou_adapted: 0.6387 - val_accuracy: 0.8485 - val_loss: 0.6017 - val_mean_iou_adapted: 0.6752 - learning_rate: 5.0000e-04
# Epoch 181/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8225 - loss: 0.6494 - mean_iou_adapted: 0.6441 - val_accuracy: 0.8345 - val_loss: 0.6360 - val_mean_iou_adapted: 0.6422 - learning_rate: 5.0000e-04
# Epoch 182/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8545 - loss: 0.6128 - mean_iou_adapted: 0.7093 - val_accuracy: 0.8337 - val_loss: 0.6422 - val_mean_iou_adapted: 0.6616 - learning_rate: 5.0000e-04
# Epoch 183/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8342 - loss: 0.6295 - mean_iou_adapted: 0.6616 - val_accuracy: 0.8550 - val_loss: 0.6153 - val_mean_iou_adapted: 0.6972 - learning_rate: 5.0000e-04
# Epoch 184/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.8465 - loss: 0.6206 - mean_iou_adapted: 0.6831 - val_accuracy: 0.8662 - val_loss: 0.5792 - val_mean_iou_adapted: 0.7114 - learning_rate: 5.0000e-04
# Epoch 185/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8329 - loss: 0.6480 - mean_iou_adapted: 0.6663 - val_accuracy: 0.7905 - val_loss: 0.7245 - val_mean_iou_adapted: 0.5339 - learning_rate: 5.0000e-04
# Epoch 186/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8470 - loss: 0.6240 - mean_iou_adapted: 0.6888 - val_accuracy: 0.8343 - val_loss: 0.6327 - val_mean_iou_adapted: 0.6594 - learning_rate: 5.0000e-04
# Epoch 187/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8452 - loss: 0.6137 - mean_iou_adapted: 0.6959 - val_accuracy: 0.8680 - val_loss: 0.6000 - val_mean_iou_adapted: 0.7119 - learning_rate: 5.0000e-04
# Epoch 188/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8288 - loss: 0.6405 - mean_iou_adapted: 0.6628 - val_accuracy: 0.8562 - val_loss: 0.5986 - val_mean_iou_adapted: 0.6841 - learning_rate: 5.0000e-04
# Epoch 189/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8506 - loss: 0.6113 - mean_iou_adapted: 0.6898 - val_accuracy: 0.8250 - val_loss: 0.6383 - val_mean_iou_adapted: 0.6483 - learning_rate: 5.0000e-04
# Epoch 190/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8642 - loss: 0.5916 - mean_iou_adapted: 0.7249 - val_accuracy: 0.8683 - val_loss: 0.5802 - val_mean_iou_adapted: 0.7140 - learning_rate: 5.0000e-04
# Epoch 191/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8433 - loss: 0.6205 - mean_iou_adapted: 0.6792 - val_accuracy: 0.8420 - val_loss: 0.6248 - val_mean_iou_adapted: 0.6792 - learning_rate: 5.0000e-04
# Epoch 192/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8395 - loss: 0.6342 - mean_iou_adapted: 0.6790 - val_accuracy: 0.8415 - val_loss: 0.6353 - val_mean_iou_adapted: 0.6724 - learning_rate: 5.0000e-04
# Epoch 193/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8401 - loss: 0.6239 - mean_iou_adapted: 0.6825 - val_accuracy: 0.8619 - val_loss: 0.5916 - val_mean_iou_adapted: 0.7040 - learning_rate: 5.0000e-04
# Epoch 194/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8424 - loss: 0.6380 - mean_iou_adapted: 0.6815 - val_accuracy: 0.8593 - val_loss: 0.6061 - val_mean_iou_adapted: 0.6939 - learning_rate: 5.0000e-04
# Epoch 195/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8291 - loss: 0.6479 - mean_iou_adapted: 0.6588 - val_accuracy: 0.8451 - val_loss: 0.6101 - val_mean_iou_adapted: 0.6781 - learning_rate: 5.0000e-04
# Epoch 196/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8489 - loss: 0.6139 - mean_iou_adapted: 0.6978 - val_accuracy: 0.8271 - val_loss: 0.6415 - val_mean_iou_adapted: 0.6465 - learning_rate: 5.0000e-04
# Epoch 197/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8647 - loss: 0.5970 - mean_iou_adapted: 0.7293 - val_accuracy: 0.8364 - val_loss: 0.6214 - val_mean_iou_adapted: 0.6670 - learning_rate: 5.0000e-04
# Epoch 198/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.7666 - loss: 0.7386 - mean_iou_adapted: 0.5706 - val_accuracy: 0.8259 - val_loss: 0.6604 - val_mean_iou_adapted: 0.6598 - learning_rate: 5.0000e-04
# Epoch 199/500
# ...
# Epoch 428/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.8829 - loss: 0.5663 - mean_iou_adapted: 0.7609 - val_accuracy: 0.8644 - val_loss: 0.5895 - val_mean_iou_adapted: 0.7182 - learning_rate: 5.0000e-04
# Epoch 429/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.8981 - loss: 0.5420 - mean_iou_adapted: 0.7884 - val_accuracy: 0.8790 - val_loss: 0.5690 - val_mean_iou_adapted: 0.7417 - learning_rate: 5.0000e-04
# Epoch 430/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8819 - loss: 0.5632 - mean_iou_adapted: 0.7568 - val_accuracy: 0.8904 - val_loss: 0.5507 - val_mean_iou_adapted: 0.7621 - learning_rate: 5.0000e-04
# Epoch 431/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9088 - loss: 0.5237 - mean_iou_adapted: 0.8046 - val_accuracy: 0.8683 - val_loss: 0.5748 - val_mean_iou_adapted: 0.7107 - learning_rate: 5.0000e-04
# Epoch 432/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8749 - loss: 0.5712 - mean_iou_adapted: 0.7384 - val_accuracy: 0.8450 - val_loss: 0.6220 - val_mean_iou_adapted: 0.6962 - learning_rate: 5.0000e-04
# Epoch 433/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9040 - loss: 0.5328 - mean_iou_adapted: 0.8043 - val_accuracy: 0.8870 - val_loss: 0.5583 - val_mean_iou_adapted: 0.7529 - learning_rate: 5.0000e-04
# Epoch 434/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.8939 - loss: 0.5408 - mean_iou_adapted: 0.7819 - val_accuracy: 0.8973 - val_loss: 0.5430 - val_mean_iou_adapted: 0.7763 - learning_rate: 5.0000e-04
# Epoch 435/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9060 - loss: 0.5248 - mean_iou_adapted: 0.8086 - val_accuracy: 0.8896 - val_loss: 0.5549 - val_mean_iou_adapted: 0.7643 - learning_rate: 5.0000e-04
# Epoch 436/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9139 - loss: 0.5179 - mean_iou_adapted: 0.8181 - val_accuracy: 0.8544 - val_loss: 0.5870 - val_mean_iou_adapted: 0.7004 - learning_rate: 5.0000e-04
# Epoch 437/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9068 - loss: 0.5247 - mean_iou_adapted: 0.8095 - val_accuracy: 0.8876 - val_loss: 0.5562 - val_mean_iou_adapted: 0.7448 - learning_rate: 5.0000e-04
# Epoch 438/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.8949 - loss: 0.5463 - mean_iou_adapted: 0.7804 - val_accuracy: 0.8622 - val_loss: 0.5879 - val_mean_iou_adapted: 0.7156 - learning_rate: 5.0000e-04
# Epoch 439/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9021 - loss: 0.5365 - mean_iou_adapted: 0.8008 - val_accuracy: 0.8921 - val_loss: 0.5497 - val_mean_iou_adapted: 0.7709 - learning_rate: 5.0000e-04
# Epoch 440/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9005 - loss: 0.5354 - mean_iou_adapted: 0.7925 - val_accuracy: 0.8884 - val_loss: 0.5625 - val_mean_iou_adapted: 0.7537 - learning_rate: 5.0000e-04
# Epoch 441/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9002 - loss: 0.5334 - mean_iou_adapted: 0.7899 - val_accuracy: 0.8947 - val_loss: 0.5529 - val_mean_iou_adapted: 0.7718 - learning_rate: 5.0000e-04
# Epoch 442/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9062 - loss: 0.5230 - mean_iou_adapted: 0.7988 - val_accuracy: 0.8923 - val_loss: 0.5523 - val_mean_iou_adapted: 0.7658 - learning_rate: 5.0000e-04
# Epoch 443/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8784 - loss: 0.5669 - mean_iou_adapted: 0.7474 - val_accuracy: 0.8756 - val_loss: 0.5732 - val_mean_iou_adapted: 0.7248 - learning_rate: 5.0000e-04
# Epoch 444/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9133 - loss: 0.5146 - mean_iou_adapted: 0.8176 - val_accuracy: 0.8799 - val_loss: 0.5715 - val_mean_iou_adapted: 0.7474 - learning_rate: 5.0000e-04
# Epoch 445/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8899 - loss: 0.5504 - mean_iou_adapted: 0.7699 - val_accuracy: 0.8933 - val_loss: 0.5434 - val_mean_iou_adapted: 0.7697 - learning_rate: 5.0000e-04
# Epoch 446/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9126 - loss: 0.5124 - mean_iou_adapted: 0.8035 - val_accuracy: 0.8729 - val_loss: 0.5831 - val_mean_iou_adapted: 0.7535 - learning_rate: 5.0000e-04
# Epoch 447/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9074 - loss: 0.5261 - mean_iou_adapted: 0.8082 - val_accuracy: 0.8449 - val_loss: 0.6495 - val_mean_iou_adapted: 0.6773 - learning_rate: 5.0000e-04
# Epoch 448/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8844 - loss: 0.5605 - mean_iou_adapted: 0.7660 - val_accuracy: 0.8987 - val_loss: 0.5533 - val_mean_iou_adapted: 0.7870 - learning_rate: 5.0000e-04
# Epoch 449/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.8968 - loss: 0.5427 - mean_iou_adapted: 0.7860 - val_accuracy: 0.8920 - val_loss: 0.5459 - val_mean_iou_adapted: 0.7615 - learning_rate: 5.0000e-04
# Epoch 450/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9074 - loss: 0.5266 - mean_iou_adapted: 0.8110 - val_accuracy: 0.8634 - val_loss: 0.5940 - val_mean_iou_adapted: 0.7102 - learning_rate: 5.0000e-04
# Epoch 451/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9219 - loss: 0.5062 - mean_iou_adapted: 0.8387 - val_accuracy: 0.9035 - val_loss: 0.5352 - val_mean_iou_adapted: 0.7955 - learning_rate: 5.0000e-04
# Epoch 452/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9207 - loss: 0.5075 - mean_iou_adapted: 0.8392 - val_accuracy: 0.8985 - val_loss: 0.5433 - val_mean_iou_adapted: 0.7828 - learning_rate: 5.0000e-04
# Epoch 453/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9044 - loss: 0.5322 - mean_iou_adapted: 0.8119 - val_accuracy: 0.8920 - val_loss: 0.5572 - val_mean_iou_adapted: 0.7672 - learning_rate: 5.0000e-04
# Epoch 454/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8878 - loss: 0.5529 - mean_iou_adapted: 0.7694 - val_accuracy: 0.8888 - val_loss: 0.5487 - val_mean_iou_adapted: 0.7632 - learning_rate: 5.0000e-04
# Epoch 455/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.9119 - loss: 0.5171 - mean_iou_adapted: 0.8165 - val_accuracy: 0.8577 - val_loss: 0.5910 - val_mean_iou_adapted: 0.7170 - learning_rate: 5.0000e-04
# Epoch 456/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9114 - loss: 0.5200 - mean_iou_adapted: 0.8188 - val_accuracy: 0.8856 - val_loss: 0.5607 - val_mean_iou_adapted: 0.7591 - learning_rate: 5.0000e-04
# Epoch 457/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9016 - loss: 0.5346 - mean_iou_adapted: 0.8091 - val_accuracy: 0.9056 - val_loss: 0.5407 - val_mean_iou_adapted: 0.8013 - learning_rate: 5.0000e-04
# Epoch 458/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8986 - loss: 0.5338 - mean_iou_adapted: 0.7926 - val_accuracy: 0.9009 - val_loss: 0.5383 - val_mean_iou_adapted: 0.7856 - learning_rate: 5.0000e-04
# Epoch 459/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.9085 - loss: 0.5280 - mean_iou_adapted: 0.8010 - val_accuracy: 0.8834 - val_loss: 0.5624 - val_mean_iou_adapted: 0.7563 - learning_rate: 5.0000e-04
# Epoch 460/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8986 - loss: 0.5333 - mean_iou_adapted: 0.7934 - val_accuracy: 0.9041 - val_loss: 0.5307 - val_mean_iou_adapted: 0.7881 - learning_rate: 5.0000e-04
# Epoch 461/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9335 - loss: 0.4857 - mean_iou_adapted: 0.8700 - val_accuracy: 0.9030 - val_loss: 0.5430 - val_mean_iou_adapted: 0.7920 - learning_rate: 5.0000e-04
# Epoch 462/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8605 - loss: 0.6051 - mean_iou_adapted: 0.7129 - val_accuracy: 0.8688 - val_loss: 0.5768 - val_mean_iou_adapted: 0.6976 - learning_rate: 5.0000e-04
# Epoch 463/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8944 - loss: 0.5495 - mean_iou_adapted: 0.7805 - val_accuracy: 0.8793 - val_loss: 0.5611 - val_mean_iou_adapted: 0.7381 - learning_rate: 5.0000e-04
# Epoch 464/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.8975 - loss: 0.5551 - mean_iou_adapted: 0.7837 - val_accuracy: 0.8925 - val_loss: 0.5481 - val_mean_iou_adapted: 0.7643 - learning_rate: 5.0000e-04
# Epoch 465/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8795 - loss: 0.5770 - mean_iou_adapted: 0.7552 - val_accuracy: 0.8986 - val_loss: 0.5392 - val_mean_iou_adapted: 0.7751 - learning_rate: 5.0000e-04
# Epoch 466/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9189 - loss: 0.5065 - mean_iou_adapted: 0.8386 - val_accuracy: 0.8957 - val_loss: 0.5444 - val_mean_iou_adapted: 0.7769 - learning_rate: 5.0000e-04
# Epoch 467/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9058 - loss: 0.5344 - mean_iou_adapted: 0.7988 - val_accuracy: 0.8633 - val_loss: 0.5942 - val_mean_iou_adapted: 0.7209 - learning_rate: 5.0000e-04
# Epoch 468/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9197 - loss: 0.5067 - mean_iou_adapted: 0.8441 - val_accuracy: 0.9067 - val_loss: 0.5311 - val_mean_iou_adapted: 0.7843 - learning_rate: 5.0000e-04
# Epoch 469/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.9052 - loss: 0.5252 - mean_iou_adapted: 0.8014 - val_accuracy: 0.8985 - val_loss: 0.5242 - val_mean_iou_adapted: 0.7748 - learning_rate: 5.0000e-04
# Epoch 470/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9220 - loss: 0.4968 - mean_iou_adapted: 0.8402 - val_accuracy: 0.8913 - val_loss: 0.5410 - val_mean_iou_adapted: 0.7620 - learning_rate: 5.0000e-04
# Epoch 471/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.9008 - loss: 0.5396 - mean_iou_adapted: 0.7898 - val_accuracy: 0.9075 - val_loss: 0.5326 - val_mean_iou_adapted: 0.7996 - learning_rate: 5.0000e-04
# Epoch 472/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9118 - loss: 0.5155 - mean_iou_adapted: 0.8163 - val_accuracy: 0.9091 - val_loss: 0.5268 - val_mean_iou_adapted: 0.7962 - learning_rate: 5.0000e-04
# Epoch 473/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8972 - loss: 0.5376 - mean_iou_adapted: 0.7859 - val_accuracy: 0.8798 - val_loss: 0.5606 - val_mean_iou_adapted: 0.7638 - learning_rate: 5.0000e-04
# Epoch 474/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.8967 - loss: 0.5383 - mean_iou_adapted: 0.7857 - val_accuracy: 0.8607 - val_loss: 0.6023 - val_mean_iou_adapted: 0.7031 - learning_rate: 5.0000e-04
# Epoch 475/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.9011 - loss: 0.5321 - mean_iou_adapted: 0.7855 - val_accuracy: 0.9023 - val_loss: 0.5286 - val_mean_iou_adapted: 0.7851 - learning_rate: 5.0000e-04
# Epoch 476/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9170 - loss: 0.5122 - mean_iou_adapted: 0.8231 - val_accuracy: 0.8535 - val_loss: 0.6407 - val_mean_iou_adapted: 0.6863 - learning_rate: 5.0000e-04
# Epoch 477/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8790 - loss: 0.5676 - mean_iou_adapted: 0.7349 - val_accuracy: 0.8970 - val_loss: 0.5413 - val_mean_iou_adapted: 0.7853 - learning_rate: 5.0000e-04
# Epoch 478/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9031 - loss: 0.5298 - mean_iou_adapted: 0.7999 - val_accuracy: 0.8852 - val_loss: 0.5615 - val_mean_iou_adapted: 0.7587 - learning_rate: 5.0000e-04
# Epoch 479/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9259 - loss: 0.4987 - mean_iou_adapted: 0.8427 - val_accuracy: 0.8909 - val_loss: 0.5468 - val_mean_iou_adapted: 0.7647 - learning_rate: 5.0000e-04
# Epoch 480/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9262 - loss: 0.5072 - mean_iou_adapted: 0.8491 - val_accuracy: 0.8903 - val_loss: 0.5597 - val_mean_iou_adapted: 0.7538 - learning_rate: 5.0000e-04
# Epoch 481/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9222 - loss: 0.4988 - mean_iou_adapted: 0.8375 - val_accuracy: 0.8705 - val_loss: 0.5940 - val_mean_iou_adapted: 0.7165 - learning_rate: 5.0000e-04
# Epoch 482/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8967 - loss: 0.5443 - mean_iou_adapted: 0.7848 - val_accuracy: 0.9004 - val_loss: 0.5428 - val_mean_iou_adapted: 0.7871 - learning_rate: 5.0000e-04
# Epoch 483/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9176 - loss: 0.5049 - mean_iou_adapted: 0.8229 - val_accuracy: 0.8883 - val_loss: 0.5649 - val_mean_iou_adapted: 0.7561 - learning_rate: 5.0000e-04
# Epoch 484/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9111 - loss: 0.5198 - mean_iou_adapted: 0.8157 - val_accuracy: 0.8890 - val_loss: 0.5689 - val_mean_iou_adapted: 0.7680 - learning_rate: 5.0000e-04
# Epoch 485/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9049 - loss: 0.5291 - mean_iou_adapted: 0.7930 - val_accuracy: 0.8839 - val_loss: 0.5582 - val_mean_iou_adapted: 0.7519 - learning_rate: 5.0000e-04
# Epoch 486/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8851 - loss: 0.5514 - mean_iou_adapted: 0.7709 - val_accuracy: 0.8877 - val_loss: 0.5579 - val_mean_iou_adapted: 0.7578 - learning_rate: 5.0000e-04
# Epoch 487/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.9057 - loss: 0.5328 - mean_iou_adapted: 0.8145 - val_accuracy: 0.8762 - val_loss: 0.5735 - val_mean_iou_adapted: 0.7360 - learning_rate: 5.0000e-04
# Epoch 488/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9138 - loss: 0.5168 - mean_iou_adapted: 0.8160 - val_accuracy: 0.9052 - val_loss: 0.5339 - val_mean_iou_adapted: 0.7874 - learning_rate: 5.0000e-04
# Epoch 489/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.8665 - loss: 0.5912 - mean_iou_adapted: 0.7092 - val_accuracy: 0.8898 - val_loss: 0.5515 - val_mean_iou_adapted: 0.7699 - learning_rate: 5.0000e-04
# Epoch 490/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9096 - loss: 0.5188 - mean_iou_adapted: 0.8174 - val_accuracy: 0.8965 - val_loss: 0.5418 - val_mean_iou_adapted: 0.7834 - learning_rate: 5.0000e-04
# Epoch 491/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.9149 - loss: 0.5031 - mean_iou_adapted: 0.8164 - val_accuracy: 0.8949 - val_loss: 0.5462 - val_mean_iou_adapted: 0.7696 - learning_rate: 5.0000e-04
# Epoch 492/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9073 - loss: 0.5259 - mean_iou_adapted: 0.8157 - val_accuracy: 0.8868 - val_loss: 0.5696 - val_mean_iou_adapted: 0.7558 - learning_rate: 5.0000e-04
# Epoch 493/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9222 - loss: 0.5004 - mean_iou_adapted: 0.8404 - val_accuracy: 0.8857 - val_loss: 0.5660 - val_mean_iou_adapted: 0.7503 - learning_rate: 5.0000e-04
# Epoch 494/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9084 - loss: 0.5260 - mean_iou_adapted: 0.8198 - val_accuracy: 0.9007 - val_loss: 0.5383 - val_mean_iou_adapted: 0.7770 - learning_rate: 5.0000e-04
# Epoch 495/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9054 - loss: 0.5235 - mean_iou_adapted: 0.8044 - val_accuracy: 0.8823 - val_loss: 0.5614 - val_mean_iou_adapted: 0.7625 - learning_rate: 5.0000e-04
# Epoch 496/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9282 - loss: 0.4946 - mean_iou_adapted: 0.8581 - val_accuracy: 0.8982 - val_loss: 0.5429 - val_mean_iou_adapted: 0.7733 - learning_rate: 5.0000e-04
# Epoch 497/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9184 - loss: 0.5045 - mean_iou_adapted: 0.8300 - val_accuracy: 0.8308 - val_loss: 0.6422 - val_mean_iou_adapted: 0.6700 - learning_rate: 5.0000e-04
# Epoch 498/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.9011 - loss: 0.5310 - mean_iou_adapted: 0.7943 - val_accuracy: 0.8788 - val_loss: 0.5602 - val_mean_iou_adapted: 0.7485 - learning_rate: 5.0000e-04
# Epoch 499/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9133 - loss: 0.5184 - mean_iou_adapted: 0.8281 - val_accuracy: 0.8693 - val_loss: 0.5771 - val_mean_iou_adapted: 0.7111 - learning_rate: 5.0000e-04
# Epoch 500/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8946 - loss: 0.5319 - mean_iou_adapted: 0.7683 - val_accuracy: 0.9130 - val_loss: 0.5125 - val_mean_iou_adapted: 0.8148 - learning_rate: 5.0000e-04

# %%
test_loss, test_accuracy, test_miou = model.evaluate(val_dataset)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test mIoU: {test_miou:.4f}")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 484ms/step - accuracy: 0.9164 - loss: 0.5039 - mean_iou_adapted: 0.8027
# Test Loss: 0.4985
# Test Accuracy: 0.9172
# Test mIoU: 0.8080

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_miou = history.history['mean_iou_adapted'] 
val_miou = history.history['val_mean_iou_adapted'] 
lr_hist = history.history['learning_rate']

# %%
epochs_range = range(len(train_loss)) 

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(epochs_range, train_loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.subplot(1, 3, 2)
plt.plot(epochs_range, train_miou, label='Training mIoU')
plt.plot(epochs_range, val_miou, label='Validation mIoU')
plt.legend(loc='lower right')
plt.title('Training and Validation mIoU')

plt.subplot(1, 3, 3)
plt.plot(epochs_range, lr_hist, label='Learning Rate')
plt.legend(loc='upper right')
plt.title('LR')

plt.show()

# %%
import pandas as pd
import pandas as pd

history_df = pd.DataFrame(history.history)
history_df['epoch'] = history_df.index + 1
history_df.to_csv("training_log_miou_0.8148.csv", index=False)

serializable_history = {k: [float(val) for val in v] for k, v in history.history.items()}
with open("training_log_miou_0.8148.json", 'w') as f:
    json.dump(serializable_history, f, indent=4)

# %%
coba = pd.read_csv("training_log_miou_0.8148.csv")
coba
# Out:
#      accuracy      loss  mean_iou_adapted  val_accuracy  val_loss  \
# 0    0.424445  1.500234          0.137459      0.528900  1.537854
# 1    0.470871  1.179650          0.187591      0.528900  1.442632
# 2    0.501439  1.099862          0.206572      0.528900  1.401080
# 3    0.499748  1.080085          0.203152      0.521256  1.386069
# 4    0.516919  1.050726          0.221800      0.540334  1.330850
# ..        ...       ...               ...           ...       ...
# 495  0.927934  0.493016          0.860415      0.898223  0.542858
# 496  0.907331  0.523037          0.809290      0.830772  0.642249
# 497  0.903116  0.528629          0.801425      0.878810  0.560241
# 498  0.907871  0.526634          0.810850      0.869348  0.577146
# 499  0.907842  0.520670          0.812009      0.912996  0.512532
#
#      val_mean_iou_adapted  learning_rate  epoch
# 0                0.075557         0.0005      1
# 1                0.075557         0.0005      2
# 2                0.075557         0.0005      3
# 3                0.112360         0.0005      4
# 4                0.148359         0.0005      5
# ..                    ...            ...    ...
# 495              0.773253         0.0005    496
# 496              0.670045         0.0005    497
# 497              0.748521         0.0005    498
# 498              0.711108         0.0005    499
# 499              0.814769         0.0005    500
#
# [500 rows x 8 columns]

# %% [markdown]
# # Fine Tune

# %%
model_path_h5 = "model_dense_unet.h5"

custom_objects_dict = {
    'crop_to_match': crop_to_match,
    'GlobalChannelMeanPool': GlobalChannelMeanPool,
    'GlobalChannelMaxPool': GlobalChannelMaxPool,
    'channel_attention_module': channel_attention_module,
    'spatial_attention_module': spatial_attention_module,
    'cbam_block': cbam_block
}

try:
    model_h5 = tf.keras.models.load_model(
        model_path_h5,
        custom_objects=custom_objects_dict,
        compile=False 
    )
except Exception as e:
    print(f"Error loading .h5 model: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Model .h5 loaded successfully!

# %%
reduce_lr_fine_tune = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_mean_iou_adapted',
    factor=0.7,  
    patience=10, 
    mode='max',
    min_lr=1e-10,
    verbose=1
)

# %%
FINE_TUNE_LR = 1e-7

# %%
optimizer_fine_tune = tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR)

# %%
model_h5.compile(
    optimizer=optimizer_fine_tune,
    loss=combined_loss_multiclass_sparse_from_probs(alpha=0.5, beta=0.5), 
    metrics=['accuracy', mean_iou_metric] 
)

# %%
NUM_FINE_TUNE_EPOCHS = 100

# %%
history_fine_tune = model_h5.fit(
    train_dataset,             
    validation_data=test_dataset, 
    epochs=NUM_FINE_TUNE_EPOCHS,
    callbacks=[
        reduce_lr_fine_tune
    ]
)
# Out:
# Epoch 1/100
# 2025-06-03 11:08:51.733746: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_12', 136 bytes spill stores, 108 bytes spill loads
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9201 - loss: 0.4964 - mean_iou_adapted: 0.8217 - val_accuracy: 0.9130 - val_loss: 0.5114 - val_mean_iou_adapted: 0.8090 - learning_rate: 1.0000e-07
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9127 - loss: 0.5069 - mean_iou_adapted: 0.8145 - val_accuracy: 0.9130 - val_loss: 0.5115 - val_mean_iou_adapted: 0.8089 - learning_rate: 1.0000e-07
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9244 - loss: 0.4923 - mean_iou_adapted: 0.8444 - val_accuracy: 0.9130 - val_loss: 0.5112 - val_mean_iou_adapted: 0.8086 - learning_rate: 1.0000e-07
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.9198 - loss: 0.4959 - mean_iou_adapted: 0.8319 - val_accuracy: 0.9126 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8077 - learning_rate: 1.0000e-07
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9283 - loss: 0.4807 - mean_iou_adapted: 0.8489 - val_accuracy: 0.9126 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8076 - learning_rate: 1.0000e-07
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9247 - loss: 0.4877 - mean_iou_adapted: 0.8412 - val_accuracy: 0.9132 - val_loss: 0.5105 - val_mean_iou_adapted: 0.8087 - learning_rate: 1.0000e-07
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9273 - loss: 0.4853 - mean_iou_adapted: 0.8443 - val_accuracy: 0.9126 - val_loss: 0.5116 - val_mean_iou_adapted: 0.8077 - learning_rate: 1.0000e-07
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9107 - loss: 0.5145 - mean_iou_adapted: 0.8066 - val_accuracy: 0.9130 - val_loss: 0.5112 - val_mean_iou_adapted: 0.8085 - learning_rate: 1.0000e-07
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.9168 - loss: 0.5051 - mean_iou_adapted: 0.8151 - val_accuracy: 0.9128 - val_loss: 0.5111 - val_mean_iou_adapted: 0.8084 - learning_rate: 1.0000e-07
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9370 - loss: 0.4693 - mean_iou_adapted: 0.8692 - val_accuracy: 0.9124 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8075 - learning_rate: 1.0000e-07
# Epoch 11/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9095 - loss: 0.5126 - mean_iou_adapted: 0.8107
# Epoch 11: ReduceLROnPlateau reducing learning rate to 7.000000081802681e-08.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9099 - loss: 0.5121 - mean_iou_adapted: 0.8117 - val_accuracy: 0.9124 - val_loss: 0.5120 - val_mean_iou_adapted: 0.8074 - learning_rate: 1.0000e-07
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9251 - loss: 0.4914 - mean_iou_adapted: 0.8484 - val_accuracy: 0.9124 - val_loss: 0.5122 - val_mean_iou_adapted: 0.8071 - learning_rate: 7.0000e-08
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9401 - loss: 0.4657 - mean_iou_adapted: 0.8668 - val_accuracy: 0.9121 - val_loss: 0.5124 - val_mean_iou_adapted: 0.8063 - learning_rate: 7.0000e-08
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.9443 - loss: 0.4600 - mean_iou_adapted: 0.8875 - val_accuracy: 0.9121 - val_loss: 0.5121 - val_mean_iou_adapted: 0.8064 - learning_rate: 7.0000e-08
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9339 - loss: 0.4738 - mean_iou_adapted: 0.8603 - val_accuracy: 0.9124 - val_loss: 0.5117 - val_mean_iou_adapted: 0.8074 - learning_rate: 7.0000e-08
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9143 - loss: 0.5083 - mean_iou_adapted: 0.8132 - val_accuracy: 0.9122 - val_loss: 0.5123 - val_mean_iou_adapted: 0.8069 - learning_rate: 7.0000e-08
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9263 - loss: 0.4904 - mean_iou_adapted: 0.8464 - val_accuracy: 0.9127 - val_loss: 0.5117 - val_mean_iou_adapted: 0.8081 - learning_rate: 7.0000e-08
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9262 - loss: 0.4972 - mean_iou_adapted: 0.8461 - val_accuracy: 0.9130 - val_loss: 0.5114 - val_mean_iou_adapted: 0.8089 - learning_rate: 7.0000e-08
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9216 - loss: 0.4897 - mean_iou_adapted: 0.8411 - val_accuracy: 0.9129 - val_loss: 0.5111 - val_mean_iou_adapted: 0.8089 - learning_rate: 7.0000e-08
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9178 - loss: 0.4969 - mean_iou_adapted: 0.8366 - val_accuracy: 0.9129 - val_loss: 0.5113 - val_mean_iou_adapted: 0.8086 - learning_rate: 7.0000e-08
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9413 - loss: 0.4680 - mean_iou_adapted: 0.8796 - val_accuracy: 0.9134 - val_loss: 0.5105 - val_mean_iou_adapted: 0.8093 - learning_rate: 7.0000e-08
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.8922 - loss: 0.5444 - mean_iou_adapted: 0.7799 - val_accuracy: 0.9129 - val_loss: 0.5114 - val_mean_iou_adapted: 0.8086 - learning_rate: 7.0000e-08
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.9310 - loss: 0.4828 - mean_iou_adapted: 0.8614 - val_accuracy: 0.9124 - val_loss: 0.5121 - val_mean_iou_adapted: 0.8076 - learning_rate: 7.0000e-08
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9460 - loss: 0.4601 - mean_iou_adapted: 0.8897 - val_accuracy: 0.9122 - val_loss: 0.5123 - val_mean_iou_adapted: 0.8068 - learning_rate: 7.0000e-08
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9242 - loss: 0.4931 - mean_iou_adapted: 0.8416 - val_accuracy: 0.9126 - val_loss: 0.5117 - val_mean_iou_adapted: 0.8077 - learning_rate: 7.0000e-08
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9391 - loss: 0.4703 - mean_iou_adapted: 0.8755 - val_accuracy: 0.9130 - val_loss: 0.5109 - val_mean_iou_adapted: 0.8084 - learning_rate: 7.0000e-08
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9060 - loss: 0.5185 - mean_iou_adapted: 0.8013 - val_accuracy: 0.9127 - val_loss: 0.5115 - val_mean_iou_adapted: 0.8081 - learning_rate: 7.0000e-08
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9081 - loss: 0.5184 - mean_iou_adapted: 0.8048 - val_accuracy: 0.9121 - val_loss: 0.5124 - val_mean_iou_adapted: 0.8069 - learning_rate: 7.0000e-08
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9362 - loss: 0.4726 - mean_iou_adapted: 0.8682 - val_accuracy: 0.9120 - val_loss: 0.5128 - val_mean_iou_adapted: 0.8066 - learning_rate: 7.0000e-08
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9210 - loss: 0.4949 - mean_iou_adapted: 0.8309 - val_accuracy: 0.9121 - val_loss: 0.5120 - val_mean_iou_adapted: 0.8067 - learning_rate: 7.0000e-08
# Epoch 31/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9373 - loss: 0.4715 - mean_iou_adapted: 0.8661
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.899999908047903e-08.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9372 - loss: 0.4716 - mean_iou_adapted: 0.8662 - val_accuracy: 0.9128 - val_loss: 0.5109 - val_mean_iou_adapted: 0.8080 - learning_rate: 7.0000e-08
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - accuracy: 0.9316 - loss: 0.4856 - mean_iou_adapted: 0.8491 - val_accuracy: 0.9128 - val_loss: 0.5111 - val_mean_iou_adapted: 0.8079 - learning_rate: 4.9000e-08
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9186 - loss: 0.5034 - mean_iou_adapted: 0.8312 - val_accuracy: 0.9124 - val_loss: 0.5120 - val_mean_iou_adapted: 0.8073 - learning_rate: 4.9000e-08
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9231 - loss: 0.5019 - mean_iou_adapted: 0.8391 - val_accuracy: 0.9122 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8070 - learning_rate: 4.9000e-08
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9072 - loss: 0.5140 - mean_iou_adapted: 0.8115 - val_accuracy: 0.9127 - val_loss: 0.5114 - val_mean_iou_adapted: 0.8082 - learning_rate: 4.9000e-08
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9142 - loss: 0.5052 - mean_iou_adapted: 0.8186 - val_accuracy: 0.9129 - val_loss: 0.5114 - val_mean_iou_adapted: 0.8088 - learning_rate: 4.9000e-08
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9163 - loss: 0.5049 - mean_iou_adapted: 0.8266 - val_accuracy: 0.9126 - val_loss: 0.5117 - val_mean_iou_adapted: 0.8079 - learning_rate: 4.9000e-08
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9283 - loss: 0.4862 - mean_iou_adapted: 0.8537 - val_accuracy: 0.9130 - val_loss: 0.5108 - val_mean_iou_adapted: 0.8083 - learning_rate: 4.9000e-08
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9293 - loss: 0.4879 - mean_iou_adapted: 0.8562 - val_accuracy: 0.9129 - val_loss: 0.5111 - val_mean_iou_adapted: 0.8082 - learning_rate: 4.9000e-08
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9162 - loss: 0.5029 - mean_iou_adapted: 0.8294 - val_accuracy: 0.9128 - val_loss: 0.5114 - val_mean_iou_adapted: 0.8083 - learning_rate: 4.9000e-08
# Epoch 41/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9149 - loss: 0.5041 - mean_iou_adapted: 0.8224
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.4300000351095146e-08.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9152 - loss: 0.5037 - mean_iou_adapted: 0.8232 - val_accuracy: 0.9126 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8077 - learning_rate: 4.9000e-08
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9409 - loss: 0.4642 - mean_iou_adapted: 0.8765 - val_accuracy: 0.9126 - val_loss: 0.5117 - val_mean_iou_adapted: 0.8080 - learning_rate: 3.4300e-08
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9288 - loss: 0.4883 - mean_iou_adapted: 0.8518 - val_accuracy: 0.9128 - val_loss: 0.5113 - val_mean_iou_adapted: 0.8082 - learning_rate: 3.4300e-08
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9320 - loss: 0.4774 - mean_iou_adapted: 0.8561 - val_accuracy: 0.9127 - val_loss: 0.5116 - val_mean_iou_adapted: 0.8082 - learning_rate: 3.4300e-08
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9374 - loss: 0.4735 - mean_iou_adapted: 0.8604 - val_accuracy: 0.9127 - val_loss: 0.5115 - val_mean_iou_adapted: 0.8083 - learning_rate: 3.4300e-08
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9237 - loss: 0.4893 - mean_iou_adapted: 0.8450 - val_accuracy: 0.9132 - val_loss: 0.5110 - val_mean_iou_adapted: 0.8093 - learning_rate: 3.4300e-08
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9497 - loss: 0.4545 - mean_iou_adapted: 0.8978 - val_accuracy: 0.9132 - val_loss: 0.5109 - val_mean_iou_adapted: 0.8093 - learning_rate: 3.4300e-08
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9419 - loss: 0.4646 - mean_iou_adapted: 0.8863 - val_accuracy: 0.9130 - val_loss: 0.5107 - val_mean_iou_adapted: 0.8088 - learning_rate: 3.4300e-08
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.9471 - loss: 0.4570 - mean_iou_adapted: 0.8923 - val_accuracy: 0.9133 - val_loss: 0.5102 - val_mean_iou_adapted: 0.8092 - learning_rate: 3.4300e-08
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9314 - loss: 0.4861 - mean_iou_adapted: 0.8627 - val_accuracy: 0.9133 - val_loss: 0.5100 - val_mean_iou_adapted: 0.8092 - learning_rate: 3.4300e-08
# Epoch 51/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9311 - loss: 0.4810 - mean_iou_adapted: 0.8607
# Epoch 51: ReduceLROnPlateau reducing learning rate to 2.4010000743146518e-08.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - accuracy: 0.9308 - loss: 0.4814 - mean_iou_adapted: 0.8601 - val_accuracy: 0.9127 - val_loss: 0.5112 - val_mean_iou_adapted: 0.8078 - learning_rate: 3.4300e-08
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9403 - loss: 0.4698 - mean_iou_adapted: 0.8747 - val_accuracy: 0.9134 - val_loss: 0.5103 - val_mean_iou_adapted: 0.8092 - learning_rate: 2.4010e-08
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9273 - loss: 0.4876 - mean_iou_adapted: 0.8503 - val_accuracy: 0.9132 - val_loss: 0.5109 - val_mean_iou_adapted: 0.8089 - learning_rate: 2.4010e-08
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9360 - loss: 0.4667 - mean_iou_adapted: 0.8660 - val_accuracy: 0.9128 - val_loss: 0.5109 - val_mean_iou_adapted: 0.8081 - learning_rate: 2.4010e-08
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9521 - loss: 0.4505 - mean_iou_adapted: 0.8989 - val_accuracy: 0.9128 - val_loss: 0.5109 - val_mean_iou_adapted: 0.8081 - learning_rate: 2.4010e-08
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9241 - loss: 0.4900 - mean_iou_adapted: 0.8433 - val_accuracy: 0.9127 - val_loss: 0.5116 - val_mean_iou_adapted: 0.8080 - learning_rate: 2.4010e-08
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9443 - loss: 0.4634 - mean_iou_adapted: 0.8778 - val_accuracy: 0.9126 - val_loss: 0.5121 - val_mean_iou_adapted: 0.8077 - learning_rate: 2.4010e-08
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9313 - loss: 0.4824 - mean_iou_adapted: 0.8539 - val_accuracy: 0.9129 - val_loss: 0.5116 - val_mean_iou_adapted: 0.8084 - learning_rate: 2.4010e-08
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9203 - loss: 0.5018 - mean_iou_adapted: 0.8344 - val_accuracy: 0.9128 - val_loss: 0.5113 - val_mean_iou_adapted: 0.8083 - learning_rate: 2.4010e-08
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9293 - loss: 0.4806 - mean_iou_adapted: 0.8518 - val_accuracy: 0.9124 - val_loss: 0.5123 - val_mean_iou_adapted: 0.8077 - learning_rate: 2.4010e-08
# Epoch 61/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9414 - loss: 0.4628 - mean_iou_adapted: 0.8756
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.680700076889252e-08.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9411 - loss: 0.4632 - mean_iou_adapted: 0.8752 - val_accuracy: 0.9131 - val_loss: 0.5111 - val_mean_iou_adapted: 0.8090 - learning_rate: 2.4010e-08
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9312 - loss: 0.4834 - mean_iou_adapted: 0.8577 - val_accuracy: 0.9132 - val_loss: 0.5102 - val_mean_iou_adapted: 0.8092 - learning_rate: 1.6807e-08
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9266 - loss: 0.4858 - mean_iou_adapted: 0.8462 - val_accuracy: 0.9129 - val_loss: 0.5107 - val_mean_iou_adapted: 0.8085 - learning_rate: 1.6807e-08
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9342 - loss: 0.4813 - mean_iou_adapted: 0.8658 - val_accuracy: 0.9132 - val_loss: 0.5101 - val_mean_iou_adapted: 0.8094 - learning_rate: 1.6807e-08
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.8951 - loss: 0.5412 - mean_iou_adapted: 0.7889 - val_accuracy: 0.9130 - val_loss: 0.5106 - val_mean_iou_adapted: 0.8086 - learning_rate: 1.6807e-08
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9293 - loss: 0.4870 - mean_iou_adapted: 0.8521 - val_accuracy: 0.9132 - val_loss: 0.5101 - val_mean_iou_adapted: 0.8090 - learning_rate: 1.6807e-08
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9239 - loss: 0.4874 - mean_iou_adapted: 0.8415 - val_accuracy: 0.9128 - val_loss: 0.5108 - val_mean_iou_adapted: 0.8082 - learning_rate: 1.6807e-08
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9230 - loss: 0.4986 - mean_iou_adapted: 0.8374 - val_accuracy: 0.9126 - val_loss: 0.5115 - val_mean_iou_adapted: 0.8077 - learning_rate: 1.6807e-08
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9092 - loss: 0.5134 - mean_iou_adapted: 0.7967 - val_accuracy: 0.9126 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8079 - learning_rate: 1.6807e-08
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9312 - loss: 0.4859 - mean_iou_adapted: 0.8611 - val_accuracy: 0.9128 - val_loss: 0.5117 - val_mean_iou_adapted: 0.8084 - learning_rate: 1.6807e-08
# Epoch 71/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9225 - loss: 0.4944 - mean_iou_adapted: 0.8358
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.1764900165189829e-08.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9224 - loss: 0.4946 - mean_iou_adapted: 0.8361 - val_accuracy: 0.9131 - val_loss: 0.5109 - val_mean_iou_adapted: 0.8090 - learning_rate: 1.6807e-08
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.8957 - loss: 0.5366 - mean_iou_adapted: 0.7897 - val_accuracy: 0.9124 - val_loss: 0.5116 - val_mean_iou_adapted: 0.8076 - learning_rate: 1.1765e-08
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9181 - loss: 0.5009 - mean_iou_adapted: 0.8212 - val_accuracy: 0.9122 - val_loss: 0.5117 - val_mean_iou_adapted: 0.8072 - learning_rate: 1.1765e-08
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9266 - loss: 0.4958 - mean_iou_adapted: 0.8537 - val_accuracy: 0.9124 - val_loss: 0.5118 - val_mean_iou_adapted: 0.8077 - learning_rate: 1.1765e-08
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9103 - loss: 0.5073 - mean_iou_adapted: 0.8112 - val_accuracy: 0.9124 - val_loss: 0.5118 - val_mean_iou_adapted: 0.8076 - learning_rate: 1.1765e-08
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9062 - loss: 0.5189 - mean_iou_adapted: 0.8157 - val_accuracy: 0.9123 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8075 - learning_rate: 1.1765e-08
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9141 - loss: 0.5013 - mean_iou_adapted: 0.8208 - val_accuracy: 0.9129 - val_loss: 0.5112 - val_mean_iou_adapted: 0.8085 - learning_rate: 1.1765e-08
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - accuracy: 0.9296 - loss: 0.4849 - mean_iou_adapted: 0.8554 - val_accuracy: 0.9128 - val_loss: 0.5116 - val_mean_iou_adapted: 0.8083 - learning_rate: 1.1765e-08
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9217 - loss: 0.4937 - mean_iou_adapted: 0.8299 - val_accuracy: 0.9128 - val_loss: 0.5113 - val_mean_iou_adapted: 0.8083 - learning_rate: 1.1765e-08
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9249 - loss: 0.4909 - mean_iou_adapted: 0.8393 - val_accuracy: 0.9130 - val_loss: 0.5107 - val_mean_iou_adapted: 0.8087 - learning_rate: 1.1765e-08
# Epoch 81/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9404 - loss: 0.4689 - mean_iou_adapted: 0.8814
# Epoch 81: ReduceLROnPlateau reducing learning rate to 8.23543011563288e-09.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9398 - loss: 0.4699 - mean_iou_adapted: 0.8801 - val_accuracy: 0.9131 - val_loss: 0.5108 - val_mean_iou_adapted: 0.8089 - learning_rate: 1.1765e-08
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9253 - loss: 0.4900 - mean_iou_adapted: 0.8478 - val_accuracy: 0.9127 - val_loss: 0.5114 - val_mean_iou_adapted: 0.8083 - learning_rate: 8.2354e-09
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9308 - loss: 0.4829 - mean_iou_adapted: 0.8562 - val_accuracy: 0.9132 - val_loss: 0.5105 - val_mean_iou_adapted: 0.8094 - learning_rate: 8.2354e-09
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9349 - loss: 0.4760 - mean_iou_adapted: 0.8639 - val_accuracy: 0.9131 - val_loss: 0.5110 - val_mean_iou_adapted: 0.8091 - learning_rate: 8.2354e-09
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9186 - loss: 0.5069 - mean_iou_adapted: 0.8238 - val_accuracy: 0.9127 - val_loss: 0.5115 - val_mean_iou_adapted: 0.8083 - learning_rate: 8.2354e-09
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9266 - loss: 0.4891 - mean_iou_adapted: 0.8406 - val_accuracy: 0.9131 - val_loss: 0.5111 - val_mean_iou_adapted: 0.8090 - learning_rate: 8.2354e-09
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - accuracy: 0.9330 - loss: 0.4810 - mean_iou_adapted: 0.8445 - val_accuracy: 0.9130 - val_loss: 0.5110 - val_mean_iou_adapted: 0.8088 - learning_rate: 8.2354e-09
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9228 - loss: 0.4878 - mean_iou_adapted: 0.8390 - val_accuracy: 0.9130 - val_loss: 0.5111 - val_mean_iou_adapted: 0.8089 - learning_rate: 8.2354e-09
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9314 - loss: 0.4839 - mean_iou_adapted: 0.8606 - val_accuracy: 0.9122 - val_loss: 0.5123 - val_mean_iou_adapted: 0.8069 - learning_rate: 8.2354e-09
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9367 - loss: 0.4720 - mean_iou_adapted: 0.8643 - val_accuracy: 0.9122 - val_loss: 0.5120 - val_mean_iou_adapted: 0.8067 - learning_rate: 8.2354e-09
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9188 - loss: 0.5100 - mean_iou_adapted: 0.8323 - val_accuracy: 0.9126 - val_loss: 0.5116 - val_mean_iou_adapted: 0.8076 - learning_rate: 8.2354e-09
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9246 - loss: 0.4920 - mean_iou_adapted: 0.8438 - val_accuracy: 0.9123 - val_loss: 0.5123 - val_mean_iou_adapted: 0.8074 - learning_rate: 8.2354e-09
# Epoch 93/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9247 - loss: 0.4903 - mean_iou_adapted: 0.8380
# Epoch 93: ReduceLROnPlateau reducing learning rate to 5.764801080943016e-09.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9243 - loss: 0.4911 - mean_iou_adapted: 0.8372 - val_accuracy: 0.9127 - val_loss: 0.5118 - val_mean_iou_adapted: 0.8080 - learning_rate: 8.2354e-09
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9202 - loss: 0.4951 - mean_iou_adapted: 0.8369 - val_accuracy: 0.9130 - val_loss: 0.5113 - val_mean_iou_adapted: 0.8088 - learning_rate: 5.7648e-09
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9390 - loss: 0.4674 - mean_iou_adapted: 0.8770 - val_accuracy: 0.9129 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8086 - learning_rate: 5.7648e-09
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - accuracy: 0.9401 - loss: 0.4682 - mean_iou_adapted: 0.8795 - val_accuracy: 0.9127 - val_loss: 0.5118 - val_mean_iou_adapted: 0.8081 - learning_rate: 5.7648e-09
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9304 - loss: 0.4848 - mean_iou_adapted: 0.8514 - val_accuracy: 0.9127 - val_loss: 0.5119 - val_mean_iou_adapted: 0.8083 - learning_rate: 5.7648e-09
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9142 - loss: 0.5125 - mean_iou_adapted: 0.8201 - val_accuracy: 0.9126 - val_loss: 0.5115 - val_mean_iou_adapted: 0.8082 - learning_rate: 5.7648e-09
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9111 - loss: 0.5127 - mean_iou_adapted: 0.8027 - val_accuracy: 0.9123 - val_loss: 0.5120 - val_mean_iou_adapted: 0.8076 - learning_rate: 5.7648e-09
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.9411 - loss: 0.4615 - mean_iou_adapted: 0.8855 - val_accuracy: 0.9129 - val_loss: 0.5107 - val_mean_iou_adapted: 0.8086 - learning_rate: 5.7648e-09
